# %%
import kquant as kq
CFG = {"sampling_cnt": 150}
# API_account
def set_api_account():
    kq.set_api("KRX2308020", "EQDkUcyI3dK6oIAXqAR8BXOK4bKxHHmH")
    return None

set_api_account()

# %%
"""
General

DataLoader
    - STATUS_LOADER
    - SYMBOL_LOADER

"""
# LOADER
import datetime as dt
import pandas as pd
import kquant as kq


class STATUS_LOADER:
    """
    STATUS_LOADER : 상태 정보 추출 클래스

    Methods:
        - __init__
        - get_current_cash
        - get_status_df
    """

    def __init__(self, dict_df_result, dict_df_position) -> None:
        """
        STATUS_LOADER의 생성자

        Args:
            dict_df_result (dict(str,pd.DataFrame))
            dict_df_position (dict(str,pd.DataFrame))

        """
        self.dict_df_result = dict_df_result
        self.dict_df_position = dict_df_position

    def get_current_cash(self) -> float:
        """
        현재 보유 현금을 반환하는 메서드
            - 만약 dict_df_result에서 CASH column을 찾을 수 없다면 초기투자금인 10억을 반환합니다.

        Returns:
            float: 현재 보유 현금
        """
        _dict_df_result = self.dict_df_result
        try:
            _df_result_total = _dict_df_result["TOTAL"]
            _current_cash = (
                _df_result_total.sort_values("DATE").tail(1)["CASH"].values[0]
            )
            return _current_cash
        except:
            return 1_000_000_000.0

    def get_status_df(self) -> pd.DataFrame:
        """
        현재 보유 position 관련 정보를 반환하는 메서드

        Returns:
            pd.DataFrame: columns = [SYMBOL, CURRENT_QTY, CURRENT_PRICE, TRADE_PRICE]
        """
        current_symbol_list = list()
        _dict_df_result = self.dict_df_result
        _dict_df_position = self.dict_df_position

        _total_symbols = sorted(_dict_df_position.keys())

        for _symbol in _total_symbols:
            try:
                _symbol_result_df = _dict_df_result[_symbol]
                _symbol_position_df = _dict_df_position[_symbol]

                _current_price = (
                    _symbol_result_df.sort_values("DATE").tail(1)["PRICE"].values[0]
                )
                _trade_price = _symbol_position_df["TRADE_PRICE"].values[0]
                _current_qty = _symbol_position_df["QTY"].values[0]

                current_symbol_list.append(
                    {
                        "SYMBOL": _symbol,
                        "CURRENT_QTY": _current_qty,
                        "CURRENT_PRICE": _current_price,
                        "TRADE_PRICE": _trade_price,
                    }
                )
            except:
                pass
        return pd.DataFrame(
            current_symbol_list,
            columns=["SYMBOL", "CURRENT_QTY", "CURRENT_PRICE", "TRADE_PRICE"],
        )


class SYMBOL_LOADER:
    """
    SYMBOL_LOADER : 주식 symbol 정보 추출 클래스

    Inner_Classes :
        SYMBOl_FILTER

    Methods :
        - filter_symbols_df
        - get_symbols
        - __call__
    """

    @staticmethod
    def load_symbols_df() -> pd.DataFrame:
        """
        symbols_df를 호출하는 메서드

        Returns:
            pd.DataFrame :
        """
        symbols_df = kq.symbol_stock()
        return symbols_df

    class SYMBOL_FILTER:
        """
        SYMBOl_FILTER : 주식 symbol을 filtering 하는 클래스

        Methods :
                - filter__market
                - filter__admin_issue
                - filter__sec_type
        """

        @staticmethod
        def filter__market(symbols_df: pd.DataFrame) -> pd.DataFrame:
            """
            market에 대한 필터링을 진행하는 메서드

            Returns:
                pd.DataFrame : MARKET이 [코스닥, 유가증권]에 속하는 row만 유지
            """
            filtered_symbols_df = symbols_df[
                (symbols_df["MARKET"].isin(["코스닥", "유가증권"]))
            ].copy()
            return filtered_symbols_df

        @staticmethod
        def filter__admin_issue(symbols_df: pd.DataFrame) -> pd.DataFrame:
            """
            ADMIN_ISSUE에 대한 필터링을 진행하는 메서드

            Returns:
                pd.DataFrame : ADMIN_ISSUE가 0 인 row만 유지
            """
            filtered_symbols_df = symbols_df[(symbols_df["ADMIN_ISSUE"] == 0)].copy()
            return filtered_symbols_df

        @staticmethod
        def filter_sec_type(symbols_df: pd.DataFrame) -> pd.DataFrame:
            """
            SEC_TYPE에 대한 필터링을 진행하는 메서드

            Returns:
                pd.DataFrame : SEC_TYPE이 [ST, EF, EN]에 속하는 row만 유지
            """
            filtered_symbols_df = symbols_df[
                symbols_df["SEC_TYPE"].isin(["ST", "EF", "EN"])
            ].copy()
            return filtered_symbols_df

    def filter_symbols_df(self, symbols_df: pd.DataFrame) -> pd.DataFrame:
        """
        symbol_df 에 대한 필터링을 진행하는 메서드

        Returns:
                pd.DataFrame : SYMBOl_FILTER의 필터 메서드를 거친 row만 유지
        """
        symbol_filter = self.SYMBOL_FILTER()
        filtered_symbols_df = symbol_filter.filter__market(symbols_df)
        filtered_symbols_df = symbol_filter.filter__admin_issue(filtered_symbols_df)
        filtered_symbols_df = symbol_filter.filter_sec_type(filtered_symbols_df)
        return filtered_symbols_df

    @staticmethod
    def get_symbols(symbols_df: pd.DataFrame) -> list:
        """
        symbols_df의 symbol을 중복을 제거하여 추출하는 메서드

        Returns:
            list : symbols
        """
        symbols = sorted(set(symbols_df["SYMBOL"]))
        return symbols

    # SYMBOL_LOADER PIPELINE
    def __call__(self) -> list:
        """
        SYMBOL_LOADER의 파이프라인을 제공하는 메서드

        Returns:
            list : symbols
        """
        symbols_df = self.load_symbols_df()
        filtered_symbols_df = self.filter_symbols_df(symbols_df)
        symbols = self.get_symbols(filtered_symbols_df)
        return symbols

# %%
"""
Specific

DataLoader
    - FUNDAMENTAL_LOADER
    - PBR_PROCESSOR
    - PER_PROCESSOR
"""


class FUNDAMENTAL_LOADER:
    """
    FUNDAMENTAL_LOADER : symbol에 대한 fundamental_analysis를 위한 정보를 제공하는 클래스

    Methods :
        - __init__
        - load_recent_close
        - load_recent_marketcap
        - load_recent_netprofit
        - load_recent_capital
        - __call__
    """

    def __init__(self, symbol: str, date: dt.date) -> None:
        """
        FUNDAMENTAL_LOADER의 생성자

        Args:
            symbol (str):
            date (dt.date):

        Attr:
            symbol (str):
            date (dt.date):
            daily_stock_df (pd.DataFrame) :
                - kq.daily_stock 에서 호출
                - 현재 날짜부터 이전 7일까지 데이터
        """
        self.symbol = symbol
        self.date = date
        self.daily_stock_df = kq.daily_stock(
            symbol,
            start_date=date - dt.timedelta(days=7),
            end_date=date,
        )

    def load_recent_close(self) -> float:
        """
        가장 최근 종가를 가져온다.
        """
        daily_stock_df = self.daily_stock_df
        _close = daily_stock_df.sort_values("DATE").tail(1)["CLOSE"].values[0]
        return _close

    def load_recent_marketcap(self) -> float:
        """
        가장 최근 시가총액을 가져온다.
        """
        daily_stock_df = self.daily_stock_df
        _marketcap = daily_stock_df.sort_values("DATE").tail(1)["MARKETCAP"].values[0]
        return _marketcap

    def load_recent_netprofit(self) -> float:
        """
        공시자료 중 가장 최근 당기순이익을 가져온다.
        """
        netprofit_df = kq.account_history(self.symbol, "122700")
        netprofit_df.sort_values("YEARMONTH", inplace=True)
        _netprofit = netprofit_df.tail(1)["VALUE"].values[0]
        return _netprofit

    def load_recent_capital(self) -> float:
        """
        공시자료 중 가장 최근 총자산(총자산 - 총부채)를 가져온다.
        """
        capital_df = kq.account_history(self.symbol, "115000")
        capital_df.sort_values("YEARMONTH", inplace=True)
        _capital = capital_df.tail(1)["VALUE"].values[0]
        return _capital

    def __call__(self) -> dict:
        """
        fundmanetal analysis를 위해 필요한 데이터를 가져와서 dictionary를 반환한다.
        """
        _close = self.load_recent_close()
        _marketcap = self.load_recent_marketcap()
        _netprofit = self.load_recent_netprofit()
        _capital = self.load_recent_capital()
        return {
            "SYMBOL": self.symbol,
            "CLOSE": _close,
            "MARKETCAP": _marketcap,
            "NETPROFIT": _netprofit,
            "CAPITAL": _capital,
        }


class PBR_PROCESSOR:
    """
    FUDAMENTAL_PROCESSOR : 기본적 분석을 통한 order 생성 클래스

    Inner_Classes :
        - GET_BUYING_ORDERS
        - GET_SELLING_ORDERS

    Methods:
        - __init__

    """

    def __init__(self, fundamental_df: pd.DataFrame) -> None:
        """
        FUDAMENTAL_PROCESSOR의 생성자

        Args:
            fundamental_df (pd.DataFrame)

        fundamental_df에 PBR을 추가하고, PBR이 음수인 row는 제거하여 저장합니다.
        """
        fundamental_df["PBR"] = fundamental_df["MARKETCAP"] / (
            fundamental_df["CAPITAL"]
        )
        fundamental_df = fundamental_df[fundamental_df["PBR"] > 0]
        self.fundamental_df = fundamental_df

    class GET_BUYING_ORDERS:
        """
        GET_BUYING_ORDERS : 매수 주문을 생성하는 클래스

        Methods :
            - __init__
            - filter_position_symbols
            - get_low_pbr_df
            - append_pbr_weight
            - append_price_invest
            - append_cnt_invest
            - __call__
        """

        def __init__(
            self,
            fundamental_processor: FUNDAMENTAL_LOADER,
            daily_invest_money: float,
            position_symbols: list,
        ) -> None:
            """
            GET_BUYING_ORDERS의 생성자

            Args:
                - fundamental_processor (FUDAMENTAL_PROCESSOR의 인스턴스)
                - daily_invest_money (float)
                - position_symbols (list)
            """
            self.fundamental_processor = fundamental_processor
            self.daily_invest_money = daily_invest_money
            self.position_symbols = position_symbols

        @staticmethod
        def filter_position_symbols(
            fundamental_df: pd.DataFrame, position_symbols: list
        ) -> pd.DataFrame:
            """
            fundamental_df에서 이미 position이 있는 symbol들을 제거
                - 어느정도 분산 투자를 유지하기 위해서 입니다.

            Returns:
                pd.DataFrame : position_symbols이 filter된 fundamental_df
            """
            filtered_fundamental_df = fundamental_df[
                ~(fundamental_df["SYMBOL"].isin(position_symbols))
            ]
            return filtered_fundamental_df

        @staticmethod
        def get_low_pbr_df(fundamental_df: pd.DataFrame) -> pd.DataFrame:
            """
            fundamental_df에서 PBR이 낮은 5개를 선정하여 추출합니다.

            Returns:
                pd.DataFrame : fundamental_df의 pbr 낮은 5개 row 추출
            """
            low_pbr_df = fundamental_df.nsmallest(5, "PBR")
            return low_pbr_df

        @staticmethod
        def append_pbr_weight(low_pbr_df: pd.DataFrame) -> pd.DataFrame:
            """
            low_pbr_df에서 pbr에 따른 투자금을 구하기 위해 weight를 구합니다.
                - pbr이 낮을 수록 비율이 증가합니다.

            Returns:
                pd.DataFrame : low_pbr_df에서 "PBR_WEIGHT" column 추가
            """
            low_pbr_df["PBR_WEIGHT"] = low_pbr_df["PBR"].sum() / low_pbr_df["PBR"]
            return low_pbr_df

        @staticmethod
        def append_price_invest(
            low_pbr_df: pd.DataFrame, daily_invest_money: float
        ) -> pd.DataFrame:
            """
            low_pbr_df PBR_WEIGHT를 기준으로 투자금을 정합니다.
                - PBR_WEIGHT가 클수록 투자금이 커집니다.

            Returns:
                pd.DataFrame : low_pbr_df에서 "PRICE_INVEST" column 추가
            """
            low_pbr_df["PRICE_INVEST"] = (
                low_pbr_df["PBR_WEIGHT"] / low_pbr_df["PBR_WEIGHT"].sum()
            ) * daily_invest_money
            return low_pbr_df

        @staticmethod
        def append_cnt_invest(low_pbr_df: pd.DataFrame) -> pd.DataFrame:
            """
            low_pbr_df PRICE_INVEST를 기준으로 구매수량을 정합니다.

            Returns:
                pd.DataFrame : low_pbr_df에서 "CNT_INVEST" column 추가
            """
            low_pbr_df["CNT_INVEST"] = low_pbr_df["PRICE_INVEST"] // low_pbr_df["CLOSE"]
            return low_pbr_df

        def __call__(self) -> list:
            """
            GET_BUYING_ORDERS의 파이프라인을 제공하는 메서드

            - 추출 -
            1. fundamental_df 추출
            2. daily_invest_money 추출
            3. position_symbols 추출

            - 전처리 -
            1. position_symbols 필터링
            2. PBR_WEIGHT column 추가
            3. PRICE_INVEST column 추가
            4. CNT_INVEST column 추가

            - 결과 생성 -
            1. buying_orders 생성
                - [
                    ('symbol',count),
                    ('symbol',count),
                    ...
                ]

            Returns :
                buying_orders (list(tuple())) : 매수 주문
            """
            fundamental_df = self.fundamental_processor.fundamental_df
            daily_invest_money = self.daily_invest_money
            position_symbols = self.position_symbols

            filtered_fundamental_df = self.filter_position_symbols(
                fundamental_df, position_symbols
            )
            low_pbr_df = self.get_low_pbr_df(filtered_fundamental_df)
            low_pbr_df = self.append_pbr_weight(low_pbr_df)
            low_pbr_df = self.append_price_invest(low_pbr_df, daily_invest_money)
            low_pbr_df = self.append_cnt_invest(low_pbr_df)
            buying_orders = list(
                low_pbr_df.set_index("SYMBOL")["CNT_INVEST"]
                .astype(int)
                .to_dict()
                .items()
            )
            return buying_orders

    class GET_SELLING_ORDERS:
        """
        GET_SELLING_ORDERS : 매도 주문을 생성하는 클래스

        Methods :
            - __init__
            - get_limit_line
            - get_high_pbr_df
            - filter_position_symbols
            - __call__
        """

        def __init__(self, fundamental_processor, status_df) -> None:
            """
            GET_SELLING_ORDERS의 생성자

            Args:
                - fundamental_processor (FUDAMENTAL_PROCESSOR의 인스턴스)
                - status_df (pd.DataFrame)
            """
            self.fundamental_processor = fundamental_processor
            self.status_df = status_df

        @staticmethod
        def get_limit_line(fundamental_df: pd.DataFrame) -> float:
            """
            pbr 상위 75 % 를 한계선으로 설정하고 이를 기준값을 추출

            Returns :
                - limit_line (float)
            """
            limit_line = np.percentile(fundamental_df["PBR"], 50)
            return limit_line

        @staticmethod
        def get_high_pbr_df(
            fundamental_df: pd.DataFrame, limit_line: float
        ) -> pd.DataFrame:
            """
            limit line을 기준으로 filtering 한 pbr 상위 fundamental_df 추출

            Returns :
                - high_pbr_df (pd.DataFrame) : 상위 PBR로 필터링된 fundamental_df
            """
            high_pbr_df = fundamental_df[fundamental_df["PBR"] > limit_line]
            return high_pbr_df

        @staticmethod
        def filter_position_symbols(
            high_pbr_df: pd.DataFrame, position_symbols: list
        ) -> pd.DataFrame:
            """
            high_pbr_df중 position이 있는지 필터링

            Returns :
                - high_pbr_df (pd.DataFrame) : position으로 필터링 된 high_pbr_df 추출
            """
            filtered_position_symbols = sorted(
                set(high_pbr_df["SYMBOL"]) & set(position_symbols)
            )
            return filtered_position_symbols

        def __call__(self) -> list:
            """
            GET_SELLING_ORDERS의 파이프라인을 제공하는 메서드

            - 추출 -
            1. fundamental_df 추출
            2. status_df 추출
            3. position_symbols 추출

            - 전처리 -
            1. limit_line 추출
            2. high_pbr_df 생성
            3. high_pbr_df 필터링

            - 결과 생성 -
            1. selling_orders 생성
                - [
                    ('symbol',count),
                    ('symbol',count),
                    ...
                ]
            Returns :
                buying_orders (list(tuple())) : 매도 주문
            """
            fundamental_df = self.fundamental_processor.fundamental_df
            status_df = self.status_df
            position_symbols = sorted(set(status_df["SYMBOL"]))

            limit_line = self.get_limit_line(fundamental_df)
            high_pbr_df = self.get_high_pbr_df(fundamental_df, limit_line)
            filtered_position_symbols = self.filter_position_symbols(
                high_pbr_df, position_symbols
            )

            selling_df = status_df[status_df["SYMBOL"].isin(filtered_position_symbols)]

            selling_orders = list(
                selling_df.set_index("SYMBOL")["CURRENT_QTY"]
                .apply(lambda x: x * -1)
                .astype(int)
                .to_dict()
                .items()
            )
            return selling_orders


class PER_PROCESSOR:
    """
    FUDAMENTAL_PROCESSOR : 기본적 분석을 통한 order 생성 클래스

    Inner_Classes :
        - GET_BUYING_ORDERS
        - GET_SELLING_ORDERS

    Methods:
        - __init__

    """

    def __init__(self, fundamental_df: pd.DataFrame) -> None:
        """
        PER_PROCESSOR의 생성자

        Args:
            fundamental_df (pd.DataFrame)

        fundamental_df에 PER을 추가하고, PER이 음수인 row는 제거하여 저장합니다.
        """
        fundamental_df["PER"] = fundamental_df["MARKETCAP"] / (
            fundamental_df["NETPROFIT"]
        )
        fundamental_df = fundamental_df[fundamental_df["PER"] > 0]
        self.fundamental_df = fundamental_df

    class GET_BUYING_ORDERS:
        """
        GET_BUYING_ORDERS : 매수 주문을 생성하는 클래스

        Methods :
            - __init__
            - filter_position_symbols
            - get_low_per_df
            - append_per_weight
            - append_price_invest
            - append_cnt_invest
            - __call__
        """

        def __init__(
            self,
            fundamental_processor: FUNDAMENTAL_LOADER,
            daily_invest_money: float,
            position_symbols: list,
        ) -> None:
            """
            GET_BUYING_ORDERS의 생성자

            Args:
                - fundamental_processor (FUDAMENTAL_PROCESSOR의 인스턴스)
                - daily_invest_money (float)
                - position_symbols (list)
            """
            self.fundamental_processor = fundamental_processor
            self.daily_invest_money = daily_invest_money
            self.position_symbols = position_symbols

        @staticmethod
        def filter_position_symbols(
            fundamental_df: pd.DataFrame, position_symbols: list
        ) -> pd.DataFrame:
            """
            fundamental_df에서 이미 position이 있는 symbol들을 제거
                - 어느정도 분산 투자를 유지하기 위해서 입니다.

            Returns:
                pd.DataFrame : position_symbols이 filter된 fundamental_df
            """
            filtered_fundamental_df = fundamental_df[
                ~(fundamental_df["SYMBOL"].isin(position_symbols))
            ]
            return filtered_fundamental_df

        @staticmethod
        def get_low_per_df(fundamental_df: pd.DataFrame) -> pd.DataFrame:
            """
            fundamental_df에서 per이 낮은 5개를 선정하여 추출합니다.

            Returns:
                pd.DataFrame : fundamental_df의 per 낮은 5개 row 추출
            """
            low_per_df = fundamental_df.nsmallest(5, "PER")
            return low_per_df

        @staticmethod
        def append_per_weight(low_per_df: pd.DataFrame) -> pd.DataFrame:
            """
            low_per_df에서 per에 따른 투자금을 구하기 위해 weight를 구합니다.
                - per이 낮을 수록 비율이 증가합니다.

            Returns:
                pd.DataFrame : low_per_df에서 "per_WEIGHT" column 추가
            """
            low_per_df["PER_WEIGHT"] = low_per_df["PER"].sum() / low_per_df["PER"]
            return low_per_df

        @staticmethod
        def append_price_invest(
            low_per_df: pd.DataFrame, daily_invest_money: float
        ) -> pd.DataFrame:
            """
            low_per_df per_WEIGHT를 기준으로 투자금을 정합니다.
                - per_WEIGHT가 클수록 투자금이 커집니다.

            Returns:
                pd.DataFrame : low_per_df에서 "PRICE_INVEST" column 추가
            """
            low_per_df["PRICE_INVEST"] = (
                low_per_df["PER_WEIGHT"] / low_per_df["PER_WEIGHT"].sum()
            ) * daily_invest_money
            return low_per_df

        @staticmethod
        def append_cnt_invest(low_per_df: pd.DataFrame) -> pd.DataFrame:
            """
            low_per_df PRICE_INVEST를 기준으로 구매수량을 정합니다.

            Returns:
                pd.DataFrame : low_per_df에서 "CNT_INVEST" column 추가
            """
            low_per_df["CNT_INVEST"] = low_per_df["PRICE_INVEST"] // low_per_df["CLOSE"]
            return low_per_df

        def __call__(self) -> list:
            """
            GET_BUYING_ORDERS의 파이프라인을 제공하는 메서드

            - 추출 -
            1. fundamental_df 추출
            2. daily_invest_money 추출
            3. position_symbols 추출

            - 전처리 -
            1. position_symbols 필터링
            2. per_WEIGHT column 추가
            3. PRICE_INVEST column 추가
            4. CNT_INVEST column 추가

            - 결과 생성 -
            1. buying_orders 생성
                - [
                    ('symbol',count),
                    ('symbol',count),
                    ...
                ]

            Returns :
                buying_orders (list(tuple())) : 매수 주문
            """
            fundamental_df = self.fundamental_processor.fundamental_df
            daily_invest_money = self.daily_invest_money
            position_symbols = self.position_symbols

            filtered_fundamental_df = self.filter_position_symbols(
                fundamental_df, position_symbols
            )
            low_per_df = self.get_low_per_df(filtered_fundamental_df)
            low_per_df = self.append_per_weight(low_per_df)
            low_per_df = self.append_price_invest(low_per_df, daily_invest_money)
            low_per_df = self.append_cnt_invest(low_per_df)
            buying_orders = list(
                low_per_df.set_index("SYMBOL")["CNT_INVEST"]
                .astype(int)
                .to_dict()
                .items()
            )
            return buying_orders

    class GET_SELLING_ORDERS:
        """
        GET_SELLING_ORDERS : 매도 주문을 생성하는 클래스

        Methods :
            - __init__
            - get_limit_line
            - get_high_per_df
            - filter_position_symbols
            - __call__
        """

        def __init__(self, fundamental_processor, status_df) -> None:
            """
            GET_SELLING_ORDERS의 생성자

            Args:
                - fundamental_processor (FUDAMENTAL_PROCESSOR의 인스턴스)
                - status_df (pd.DataFrame)
            """
            self.fundamental_processor = fundamental_processor
            self.status_df = status_df

        @staticmethod
        def get_limit_line(fundamental_df: pd.DataFrame) -> float:
            """
            per 상위 75 % 를 한계선으로 설정하고 이를 기준값을 추출

            Returns :
                - limit_line (float)
            """
            limit_line = np.percentile(fundamental_df["PER"], 50)
            return limit_line

        @staticmethod
        def get_high_per_df(
            fundamental_df: pd.DataFrame, limit_line: float
        ) -> pd.DataFrame:
            """
            limit line을 기준으로 filtering 한 per 상위 fundamental_df 추출

            Returns :
                - high_per_df (pd.DataFrame) : 상위 per로 필터링된 fundamental_df
            """
            high_per_df = fundamental_df[fundamental_df["PER"] > limit_line]
            return high_per_df

        @staticmethod
        def filter_position_symbols(
            high_per_df: pd.DataFrame, position_symbols: list
        ) -> pd.DataFrame:
            """
            high_per_df중 position이 있는지 필터링

            Returns :
                - high_per_df (pd.DataFrame) : position으로 필터링 된 high_per_df 추출
            """
            filtered_position_symbols = sorted(
                set(high_per_df["SYMBOL"]) & set(position_symbols)
            )
            return filtered_position_symbols

        def __call__(self) -> list:
            """
            GET_SELLING_ORDERS의 파이프라인을 제공하는 메서드

            - 추출 -
            1. fundamental_df 추출
            2. status_df 추출
            3. position_symbols 추출

            - 전처리 -
            1. limit_line 추출
            2. high_per_df 생성
            3. high_per_df 필터링

            - 결과 생성 -
            1. selling_orders 생성
                - [
                    ('symbol',count),
                    ('symbol',count),
                    ...
                ]
            Returns :
                buying_orders (list(tuple())) : 매도 주문
            """
            fundamental_df = self.fundamental_processor.fundamental_df
            status_df = self.status_df
            position_symbols = sorted(set(status_df["SYMBOL"]))

            limit_line = self.get_limit_line(fundamental_df)
            high_per_df = self.get_high_per_df(fundamental_df, limit_line)
            filtered_position_symbols = self.filter_position_symbols(
                high_per_df, position_symbols
            )

            selling_df = status_df[status_df["SYMBOL"].isin(filtered_position_symbols)]

            selling_orders = list(
                selling_df.set_index("SYMBOL")["CURRENT_QTY"]
                .apply(lambda x: x * -1)
                .astype(int)
                .to_dict()
                .items()
            )
            return selling_orders

# %%
import random
import logging
import datetime as dt
import pandas as pd


def trade_func(
    date: dt.date,
    dict_df_result: dict[str, pd.DataFrame],
    dict_df_position: dict[str, pd.DataFrame],
    logger: logging.Logger,
) -> list[tuple[str, int]]:
    """
    STATUS_LOADER
        : get_current_cash()
            -> 현재 가용 가능한 현금을 가져옵니다.
        : get_status_df()
            -> 현재 포지션이 있는 주식들에 대한 정보를 가져옵니다.
    """
    status_loader = STATUS_LOADER(dict_df_result, dict_df_position)

    current_cash = status_loader.get_current_cash()
    daily_invest_money = current_cash / 2
    status_df = status_loader.get_status_df()
    position_symbols = sorted(set(status_df["SYMBOL"]))

    """
    SYMBOL_LOADER
        : __call__()
            -> 현재 시장에서 거래 가능한 symbol을 모두 가져옵니다.
    """
    symbol_loader = SYMBOL_LOADER()
    total_symbols = symbol_loader()

    sampled_symbols = random.sample(total_symbols, CFG["sampling_cnt"])
    using_symbols = sorted(set(sampled_symbols + position_symbols))
    """
    FUNDAMENTAL_LOADER
        : __call__()
            -> 특정 symbol에 대하여, fundamental anlysis를 위해 필요한 데이터를 추출합니다.
    """

    fundamental_data_list = list()
    for symbol in using_symbols:
        try:
            _fundamental_loader = FUNDAMENTAL_LOADER(symbol, date)
            _fundamental_data = _fundamental_loader()
            fundamental_data_list.append(_fundamental_data)
        except:
            pass
    fundamental_df = pd.DataFrame(fundamental_data_list)

    """
    PER_PROCESSOR
        : GET_BUYING_ORDERS
        : GET_SELLING_ORDERS
    """
    per_invest_money = daily_invest_money / 2
    fundamental_processor = PER_PROCESSOR(fundamental_df)

    get_buying_orders = PER_PROCESSOR.GET_BUYING_ORDERS(
        fundamental_processor, per_invest_money, position_symbols
    )
    buying_orders = get_buying_orders()
    get_selling_orders = PER_PROCESSOR.GET_SELLING_ORDERS(
        fundamental_processor, status_df
    )
    selling_orders = get_selling_orders()

    symbols_and_orders_per = buying_orders + selling_orders

    """
    PBR_PROCESSOR
        : GET_BUYING_ORDERS
        : GET_SELLING_ORDERS
    """
    pbr_invest_money = daily_invest_money / 2
    fundamental_processor = PBR_PROCESSOR(fundamental_df)

    get_buying_orders = PBR_PROCESSOR.GET_BUYING_ORDERS(
        fundamental_processor, pbr_invest_money, position_symbols
    )
    buying_orders = get_buying_orders()
    get_selling_orders = PBR_PROCESSOR.GET_SELLING_ORDERS(
        fundamental_processor, status_df
    )
    selling_orders = get_selling_orders()

    symbols_and_orders_pbr = buying_orders + selling_orders

    ## CONCAT
    symbols_and_orders_df = pd.DataFrame(
        symbols_and_orders_pbr + symbols_and_orders_per, columns=["SYMBOL", "ORDER"]
    )
    symbols_and_orders = list(
        symbols_and_orders_df.groupby("SYMBOL").sum().squeeze().to_dict().items()
    )
    return symbols_and_orders

# %%
# loop
dict_df_result = kq.backtest_stock_port_daily(
    trade_func,
    "2023-08-01",  # 실제 심사에서는 투자기간 시작일
    "2023-08-31",  # 실제 심사에서는 투자기간 종료일
    init_cash=1_000_000_000,  # 10억원
)
# Out:
# [2023-08-01] 종목: 001130, 주문전 보유수량:      0 주문수량:    343, 매매수량:    343, 주문후 보유수량:    343
# [2023-08-01] 종목: 001500, 주문전 보유수량:      0 주문수량:  9,638, 매매수량:  9,638, 주문후 보유수량:  9,638
# [2023-08-01] 종목: 004360, 주문전 보유수량:      0 주문수량:  7,295, 매매수량:  7,295, 주문후 보유수량:  7,295
# [2023-08-01] 종목: 006840, 주문전 보유수량:      0 주문수량:  2,551, 매매수량:  2,551, 주문후 보유수량:  2,551
# [2023-08-01] 종목: 016380, 주문전 보유수량:      0 주문수량:  7,368, 매매수량:  7,368, 주문후 보유수량:  7,368
# [2023-08-01] 종목: 054800, 주문전 보유수량:      0 주문수량: 11,003, 매매수량: 11,003, 주문후 보유수량: 11,003
# [2023-08-01] 종목: 290120, 주문전 보유수량:      0 주문수량:  8,321, 매매수량:  8,321, 주문후 보유수량:  8,321
# [2023-08-02] 종목: 004150, 주문전 보유수량:      0 주문수량: 15,520, 매매수량: 15,520, 주문후 보유수량: 15,520
# [2023-08-02] 종목: 005960, 주문전 보유수량:      0 주문수량:  3,315, 매매수량:  3,315, 주문후 보유수량:  3,315
# [2023-08-02] 종목: 021820, 주문전 보유수량:      0 주문수량:  4,815, 매매수량:  4,815, 주문후 보유수량:  4,815
# [2023-08-02] 종목: 078930, 주문전 보유수량:      0 주문수량:  1,535, 매매수량:  1,535, 주문후 보유수량:  1,535
# [2023-08-02] 종목: 124560, 주문전 보유수량:      0 주문수량:  8,632, 매매수량:  8,632, 주문후 보유수량:  8,632
# [2023-08-02] 종목: 227840, 주문전 보유수량:      0 주문수량:  1,497, 매매수량:  1,497, 주문후 보유수량:  1,497
# [2023-08-02] 종목: 316140, 주문전 보유수량:      0 주문수량:  3,344, 매매수량:  3,344, 주문후 보유수량:  3,344
# [2023-08-03] 종목: 000370, 주문전 보유수량:      0 주문수량:  3,316, 매매수량:  3,316, 주문후 보유수량:  3,316
# [2023-08-03] 종목: 001720, 주문전 보유수량:      0 주문수량:    168, 매매수량:    168, 주문후 보유수량:    168
# [2023-08-03] 종목: 029460, 주문전 보유수량:      0 주문수량:  1,315, 매매수량:  1,315, 주문후 보유수량:  1,315
# [2023-08-03] 종목: 055550, 주문전 보유수량:      0 주문수량:    494, 매매수량:    494, 주문후 보유수량:    494
# [2023-08-03] 종목: 129260, 주문전 보유수량:      0 주문수량:  9,963, 매매수량:  9,963, 주문후 보유수량:  9,963
# [2023-08-03] 종목: 139480, 주문전 보유수량:      0 주문수량:    469, 매매수량:    469, 주문후 보유수량:    469
# [2023-08-04] 종목: 000370, 주문전 보유수량:  3,316 주문수량: -3,316, 매매수량: -3,316, 주문후 보유수량:      0
# [2023-08-04] 종목: 001720, 주문전 보유수량:    168 주문수량:   -168, 매매수량:   -168, 주문후 보유수량:      0
# [2023-08-04] 종목: 000540, 주문전 보유수량:      0 주문수량:  2,038, 매매수량:  2,038, 주문후 보유수량:  2,038
# [2023-08-04] 종목: 004960, 주문전 보유수량:      0 주문수량:  1,925, 매매수량:  1,925, 주문후 보유수량:  1,925
# [2023-08-04] 종목: 106240, 주문전 보유수량:      0 주문수량: 13,604, 매매수량: 13,604, 주문후 보유수량: 13,604
# [2023-08-04] 종목: 140520, 주문전 보유수량:      0 주문수량:  2,660, 매매수량:  2,660, 주문후 보유수량:  2,660
# [2023-08-04] 종목: 175330, 주문전 보유수량:      0 주문수량:    621, 매매수량:    621, 주문후 보유수량:    621
# [2023-08-07] 종목: 001390, 주문전 보유수량:      0 주문수량:  2,056, 매매수량:  2,056, 주문후 보유수량:  2,056
# [2023-08-07] 종목: 001620, 주문전 보유수량:      0 주문수량:  4,820, 매매수량:  4,820, 주문후 보유수량:  4,820
# [2023-08-07] 종목: 004720, 주문전 보유수량:      0 주문수량:    856, 매매수량:    856, 주문후 보유수량:    856
# [2023-08-07] 종목: 009440, 주문전 보유수량:      0 주문수량:    974, 매매수량:    974, 주문후 보유수량:    974
# [2023-08-07] 종목: 024070, 주문전 보유수량:      0 주문수량:  1,001, 매매수량:  1,001, 주문후 보유수량:  1,001
# [2023-08-07] 종목: 031330, 주문전 보유수량:      0 주문수량:    532, 매매수량:    532, 주문후 보유수량:    532
# [2023-08-07] 종목: 069730, 주문전 보유수량:      0 주문수량:    373, 매매수량:    373, 주문후 보유수량:    373
# [2023-08-07] 종목: 071320, 주문전 보유수량:      0 주문수량:    240, 매매수량:    240, 주문후 보유수량:    240
# [2023-08-07] 종목: 214180, 주문전 보유수량:      0 주문수량:     98, 매매수량:     98, 주문후 보유수량:     98
# [2023-08-08] 종목: 001620, 주문전 보유수량:  4,820 주문수량: -4,820, 매매수량: -4,820, 주문후 보유수량:      0
# [2023-08-08] 종목: 000860, 주문전 보유수량:      0 주문수량:    119, 매매수량:    119, 주문후 보유수량:    119
# [2023-08-08] 종목: 001120, 주문전 보유수량:      0 주문수량:     47, 매매수량:     47, 주문후 보유수량:     47
# [2023-08-08] 종목: 002020, 주문전 보유수량:      0 주문수량:    272, 매매수량:    272, 주문후 보유수량:    272
# [2023-08-08] 종목: 003070, 주문전 보유수량:      0 주문수량:    158, 매매수량:    158, 주문후 보유수량:    158
# [2023-08-08] 종목: 006390, 주문전 보유수량:      0 주문수량:    154, 매매수량:    154, 주문후 보유수량:    154
# [2023-08-08] 종목: 009580, 주문전 보유수량:      0 주문수량:    468, 매매수량:    468, 주문후 보유수량:    468
# [2023-08-08] 종목: 016250, 주문전 보유수량:      0 주문수량:    178, 매매수량:    178, 주문후 보유수량:    178
# [2023-08-08] 종목: 025530, 주문전 보유수량:      0 주문수량:    590, 매매수량:    590, 주문후 보유수량:    590
# [2023-08-09] 종목: 000860, 주문전 보유수량:    119 주문수량:   -119, 매매수량:   -119, 주문후 보유수량:      0
# [2023-08-09] 종목: 001130, 주문전 보유수량:    343 주문수량:   -343, 매매수량:   -343, 주문후 보유수량:      0
# [2023-08-09] 종목: 006390, 주문전 보유수량:    154 주문수량:   -154, 매매수량:   -154, 주문후 보유수량:      0
# [2023-08-09] 종목: 021820, 주문전 보유수량:  4,815 주문수량: -4,815, 매매수량: -4,815, 주문후 보유수량:      0
# [2023-08-09] 종목: 025530, 주문전 보유수량:    590 주문수량:   -590, 매매수량:   -590, 주문후 보유수량:      0
# [2023-08-09] 종목: 031330, 주문전 보유수량:    532 주문수량:   -532, 매매수량:   -532, 주문후 보유수량:      0
# [2023-08-09] 종목: 069730, 주문전 보유수량:    373 주문수량:   -373, 매매수량:   -373, 주문후 보유수량:      0
# [2023-08-09] 종목: 124560, 주문전 보유수량:  8,632 주문수량: -8,632, 매매수량: -8,632, 주문후 보유수량:      0
# [2023-08-09] <KQuantNotAllowShort> 공매도 금지 오류: 매도 수량이 현재 보유수량보다 큼
# [2023-08-09] 종목: 214180, 주문전 보유수량:     98 주문수량:   -196, 매매수량:      0, 주문후 보유수량:     98
# [2023-08-09] 종목: 290120, 주문전 보유수량:  8,321 주문수량: -8,321, 매매수량: -8,321, 주문후 보유수량:      0
# [2023-08-09] 종목: 000320, 주문전 보유수량:      0 주문수량:    112, 매매수량:    112, 주문후 보유수량:    112
# [2023-08-09] 종목: 000950, 주문전 보유수량:      0 주문수량:    143, 매매수량:    143, 주문후 보유수량:    143
# [2023-08-09] 종목: 003200, 주문전 보유수량:      0 주문수량:     84, 매매수량:     84, 주문후 보유수량:     84
# [2023-08-09] 종목: 009970, 주문전 보유수량:      0 주문수량:     18, 매매수량:     18, 주문후 보유수량:     18
# [2023-08-09] 종목: 023600, 주문전 보유수량:      0 주문수량:     71, 매매수량:     71, 주문후 보유수량:     71
# [2023-08-09] 종목: 027410, 주문전 보유수량:      0 주문수량:    362, 매매수량:    362, 주문후 보유수량:    362
# [2023-08-09] 종목: 028080, 주문전 보유수량:      0 주문수량:    183, 매매수량:    183, 주문후 보유수량:    183
# [2023-08-09] 종목: 124500, 주문전 보유수량:      0 주문수량:    179, 매매수량:    179, 주문후 보유수량:    179
# [2023-08-09] 종목: 294870, 주문전 보유수량:      0 주문수량:    113, 매매수량:    113, 주문후 보유수량:    113
# [2023-08-10] 종목: 027410, 주문전 보유수량:    362 주문수량:   -362, 매매수량:   -362, 주문후 보유수량:      0
# [2023-08-10] <KQuantNotAllowShort> 공매도 금지 오류: 매도 수량이 현재 보유수량보다 큼
# [2023-08-10] 종목: 214180, 주문전 보유수량:     98 주문수량:   -196, 매매수량:      0, 주문후 보유수량:     98
# [2023-08-10] 종목: 294870, 주문전 보유수량:    113 주문수량:   -113, 매매수량:   -113, 주문후 보유수량:      0
# [2023-08-10] 종목: 000070, 주문전 보유수량:      0 주문수량:     91, 매매수량:     91, 주문후 보유수량:     91
# [2023-08-10] 종목: 001040, 주문전 보유수량:      0 주문수량:    226, 매매수량:    226, 주문후 보유수량:    226
# [2023-08-10] 종목: 009200, 주문전 보유수량:      0 주문수량:  7,382, 매매수량:  7,382, 주문후 보유수량:  7,382
# [2023-08-10] 종목: 009410, 주문전 보유수량:      0 주문수량:  3,479, 매매수량:  3,479, 주문후 보유수량:  3,479
# [2023-08-10] 종목: 024800, 주문전 보유수량:      0 주문수량: 10,524, 매매수량: 10,524, 주문후 보유수량: 10,524
# [2023-08-10] 종목: 094970, 주문전 보유수량:      0 주문수량:  3,094, 매매수량:  3,094, 주문후 보유수량:  3,094
# [2023-08-11] 종목: 000070, 주문전 보유수량:     91 주문수량:    -91, 매매수량:    -91, 주문후 보유수량:      0
# [2023-08-11] <KQuantNotAllowShort> 공매도 금지 오류: 매도 수량이 현재 보유수량보다 큼
# [2023-08-11] 종목: 214180, 주문전 보유수량:     98 주문수량:   -196, 매매수량:      0, 주문후 보유수량:     98
# [2023-08-11] 종목: 001130, 주문전 보유수량:      0 주문수량:     28, 매매수량:     28, 주문후 보유수량:     28
# [2023-08-11] 종목: 002820, 주문전 보유수량:      0 주문수량:  1,412, 매매수량:  1,412, 주문후 보유수량:  1,412
# [2023-08-11] 종목: 034810, 주문전 보유수량:      0 주문수량:    986, 매매수량:    986, 주문후 보유수량:    986
# [2023-08-11] 종목: 039560, 주문전 보유수량:      0 주문수량:  1,706, 매매수량:  1,706, 주문후 보유수량:  1,706
# [2023-08-11] 종목: 058650, 주문전 보유수량:      0 주문수량:     93, 매매수량:     93, 주문후 보유수량:     93
# [2023-08-11] 종목: 119850, 주문전 보유수량:      0 주문수량:    953, 매매수량:    953, 주문후 보유수량:    953
# [2023-08-11] 종목: 363280, 주문전 보유수량:      0 주문수량:    905, 매매수량:    905, 주문후 보유수량:    905
# [2023-08-14] 종목: 094970, 주문전 보유수량:  3,094 주문수량: -3,094, 매매수량: -3,094, 주문후 보유수량:      0
# [2023-08-14] 종목: 119850, 주문전 보유수량:    953 주문수량:   -953, 매매수량:   -953, 주문후 보유수량:      0
# [2023-08-14] <KQuantNotAllowShort> 공매도 금지 오류: 매도 수량이 현재 보유수량보다 큼
# [2023-08-14] 종목: 214180, 주문전 보유수량:     98 주문수량:   -196, 매매수량:      0, 주문후 보유수량:     98
# [2023-08-14] 종목: 000140, 주문전 보유수량:      0 주문수량:    615, 매매수량:    615, 주문후 보유수량:    615
# [2023-08-14] 종목: 000180, 주문전 보유수량:      0 주문수량:  1,287, 매매수량:  1,287, 주문후 보유수량:  1,287
# [2023-08-14] 종목: 005710, 주문전 보유수량:      0 주문수량:    335, 매매수량:    335, 주문후 보유수량:    335
# [2023-08-14] 종목: 032940, 주문전 보유수량:      0 주문수량:  1,478, 매매수량:  1,478, 주문후 보유수량:  1,478
# [2023-08-14] 종목: 034120, 주문전 보유수량:      0 주문수량:     65, 매매수량:     65, 주문후 보유수량:     65
# [2023-08-14] 종목: 057050, 주문전 보유수량:      0 주문수량:     50, 매매수량:     50, 주문후 보유수량:     50
# [2023-08-14] 종목: 137310, 주문전 보유수량:      0 주문수량:    302, 매매수량:    302, 주문후 보유수량:    302
# [2023-08-14] 종목: 294870, 주문전 보유수량:      0 주문수량:    253, 매매수량:    253, 주문후 보유수량:    253
# [2023-08-16] 종목: 001130, 주문전 보유수량:     28 주문수량:    -28, 매매수량:    -28, 주문후 보유수량:      0
# [2023-08-16] 종목: 034120, 주문전 보유수량:     65 주문수량:    -65, 매매수량:    -65, 주문후 보유수량:      0
# [2023-08-16] 종목: 057050, 주문전 보유수량:     50 주문수량:    -50, 매매수량:    -50, 주문후 보유수량:      0
# [2023-08-16] <KQuantNotAllowShort> 공매도 금지 오류: 매도 수량이 현재 보유수량보다 큼
# [2023-08-16] 종목: 214180, 주문전 보유수량:     98 주문수량:   -196, 매매수량:      0, 주문후 보유수량:     98
# [2023-08-16] 종목: 294870, 주문전 보유수량:    253 주문수량:   -253, 매매수량:   -253, 주문후 보유수량:      0
# [2023-08-16] 종목: 000150, 주문전 보유수량:      0 주문수량:     21, 매매수량:     21, 주문후 보유수량:     21
# [2023-08-16] 종목: 004170, 주문전 보유수량:      0 주문수량:      5, 매매수량:      5, 주문후 보유수량:      5
# [2023-08-16] 종목: 012620, 주문전 보유수량:      0 주문수량:    156, 매매수량:    156, 주문후 보유수량:    156
# [2023-08-16] 종목: 028670, 주문전 보유수량:      0 주문수량:    309, 매매수량:    309, 주문후 보유수량:    309
# [2023-08-16] 종목: 035510, 주문전 보유수량:      0 주문수량:    127, 매매수량:    127, 주문후 보유수량:    127
# [2023-08-16] 종목: 039020, 주문전 보유수량:      0 주문수량:    660, 매매수량:    660, 주문후 보유수량:    660
# [2023-08-16] 종목: 067830, 주문전 보유수량:      0 주문수량:    630, 매매수량:    630, 주문후 보유수량:    630
# [2023-08-16] 종목: 071840, 주문전 보유수량:      0 주문수량:    514, 매매수량:    514, 주문후 보유수량:    514
# [2023-08-16] 종목: 244920, 주문전 보유수량:      0 주문수량:    747, 매매수량:    747, 주문후 보유수량:    747
# [2023-08-17] 종목: 028670, 주문전 보유수량:    309 주문수량:   -309, 매매수량:   -309, 주문후 보유수량:      0
# [2023-08-17] 종목: 035510, 주문전 보유수량:    127 주문수량:   -127, 매매수량:   -127, 주문후 보유수량:      0
# [2023-08-17] 종목: 039020, 주문전 보유수량:    660 주문수량:   -660, 매매수량:   -660, 주문후 보유수량:      0
# [2023-08-17] 종목: 039560, 주문전 보유수량:  1,706 주문수량: -1,706, 매매수량: -1,706, 주문후 보유수량:      0
# [2023-08-17] 종목: 137310, 주문전 보유수량:    302 주문수량:   -302, 매매수량:   -302, 주문후 보유수량:      0
# [2023-08-17] <KQuantNotAllowShort> 공매도 금지 오류: 매도 수량이 현재 보유수량보다 큼
# [2023-08-17] 종목: 214180, 주문전 보유수량:     98 주문수량:   -196, 매매수량:      0, 주문후 보유수량:     98
# [2023-08-17] 종목: 244920, 주문전 보유수량:    747 주문수량:   -747, 매매수량:   -747, 주문후 보유수량:      0
# [2023-08-17] 종목: 004690, 주문전 보유수량:      0 주문수량:     12, 매매수량:     12, 주문후 보유수량:     12
# [2023-08-17] 종목: 007160, 주문전 보유수량:      0 주문수량:     71, 매매수량:     71, 주문후 보유수량:     71
# [2023-08-17] 종목: 013120, 주문전 보유수량:      0 주문수량:    287, 매매수량:    287, 주문후 보유수량:    287
# [2023-08-17] 종목: 015860, 주문전 보유수량:      0 주문수량:    424, 매매수량:    424, 주문후 보유수량:    424
# [2023-08-17] 종목: 038060, 주문전 보유수량:      0 주문수량:    598, 매매수량:    598, 주문후 보유수량:    598
# [2023-08-17] 종목: 139130, 주문전 보유수량:      0 주문수량:    451, 매매수량:    451, 주문후 보유수량:    451
# [2023-08-17] 종목: 317400, 주문전 보유수량:      0 주문수량:    829, 매매수량:    829, 주문후 보유수량:    829
# [2023-08-18] 종목: 004690, 주문전 보유수량:     12 주문수량:    -12, 매매수량:    -12, 주문후 보유수량:      0
# [2023-08-18] 종목: 015860, 주문전 보유수량:    424 주문수량:   -424, 매매수량:   -424, 주문후 보유수량:      0
# [2023-08-18] 종목: 038060, 주문전 보유수량:    598 주문수량:   -598, 매매수량:   -598, 주문후 보유수량:      0
# [2023-08-18] 종목: 067830, 주문전 보유수량:    630 주문수량:   -630, 매매수량:   -630, 주문후 보유수량:      0
# [2023-08-18] <KQuantNotAllowShort> 공매도 금지 오류: 매도 수량이 현재 보유수량보다 큼
# [2023-08-18] 종목: 214180, 주문전 보유수량:     98 주문수량:   -196, 매매수량:      0, 주문후 보유수량:     98
# [2023-08-18] 종목: 000050, 주문전 보유수량:      0 주문수량:    176, 매매수량:    176, 주문후 보유수량:    176
# [2023-08-18] 종목: 002320, 주문전 보유수량:      0 주문수량:    119, 매매수량:    119, 주문후 보유수량:    119
# [2023-08-18] 종목: 004560, 주문전 보유수량:      0 주문수량:    124, 매매수량:    124, 주문후 보유수량:    124
# [2023-08-18] 종목: 010950, 주문전 보유수량:      0 주문수량:     18, 매매수량:     18, 주문후 보유수량:     18
# [2023-08-18] 종목: 011760, 주문전 보유수량:      0 주문수량:     75, 매매수량:     75, 주문후 보유수량:     75
# [2023-08-18] 종목: 033160, 주문전 보유수량:      0 주문수량:    117, 매매수량:    117, 주문후 보유수량:    117
# [2023-08-18] 종목: 044450, 주문전 보유수량:      0 주문수량:    156, 매매수량:    156, 주문후 보유수량:    156
# [2023-08-18] 종목: 047040, 주문전 보유수량:      0 주문수량:    326, 매매수량:    326, 주문후 보유수량:    326
# [2023-08-18] 종목: 130740, 주문전 보유수량:      0 주문수량:    620, 매매수량:    620, 주문후 보유수량:    620
# [2023-08-18] 종목: 137310, 주문전 보유수량:      0 주문수량:    290, 매매수량:    290, 주문후 보유수량:    290
# [2023-08-21] 종목: 000050, 주문전 보유수량:    176 주문수량:   -176, 매매수량:   -176, 주문후 보유수량:      0
# [2023-08-21] 종목: 000320, 주문전 보유수량:    112 주문수량:   -112, 매매수량:   -112, 주문후 보유수량:      0
# [2023-08-21] 종목: 002320, 주문전 보유수량:    119 주문수량:   -119, 매매수량:   -119, 주문후 보유수량:      0
# [2023-08-21] 종목: 004560, 주문전 보유수량:    124 주문수량:   -124, 매매수량:   -124, 주문후 보유수량:      0
# [2023-08-21] 종목: 009580, 주문전 보유수량:    468 주문수량:   -468, 매매수량:   -468, 주문후 보유수량:      0
# [2023-08-21] 종목: 010950, 주문전 보유수량:     18 주문수량:    -18, 매매수량:    -18, 주문후 보유수량:      0
# [2023-08-21] 종목: 011760, 주문전 보유수량:     75 주문수량:    -75, 매매수량:    -75, 주문후 보유수량:      0
# [2023-08-21] 종목: 033160, 주문전 보유수량:    117 주문수량:   -117, 매매수량:   -117, 주문후 보유수량:      0
# [2023-08-21] 종목: 047040, 주문전 보유수량:    326 주문수량:   -326, 매매수량:   -326, 주문후 보유수량:      0
# [2023-08-21] 종목: 130740, 주문전 보유수량:    620 주문수량:   -620, 매매수량:   -620, 주문후 보유수량:      0
# [2023-08-21] 종목: 137310, 주문전 보유수량:    290 주문수량:   -290, 매매수량:   -290, 주문후 보유수량:      0
# [2023-08-21] <KQuantNotAllowShort> 공매도 금지 오류: 매도 수량이 현재 보유수량보다 큼
# [2023-08-21] 종목: 214180, 주문전 보유수량:     98 주문수량:   -196, 매매수량:      0, 주문후 보유수량:     98
# [2023-08-21] 종목: 000760, 주문전 보유수량:      0 주문수량:    100, 매매수량:    100, 주문후 보유수량:    100
# [2023-08-21] 종목: 000850, 주문전 보유수량:      0 주문수량:     92, 매매수량:     92, 주문후 보유수량:     92
# [2023-08-21] 종목: 002310, 주문전 보유수량:      0 주문수량:     29, 매매수량:     29, 주문후 보유수량:     29
# [2023-08-21] 종목: 011170, 주문전 보유수량:      0 주문수량:      7, 매매수량:      7, 주문후 보유수량:      7
# [2023-08-21] 종목: 016590, 주문전 보유수량:      0 주문수량:    335, 매매수량:    335, 주문후 보유수량:    335
# [2023-08-21] 종목: 028670, 주문전 보유수량:      0 주문수량:    245, 매매수량:    245, 주문후 보유수량:    245
# [2023-08-21] 종목: 082850, 주문전 보유수량:      0 주문수량:    488, 매매수량:    488, 주문후 보유수량:    488
# [2023-08-21] 종목: 145990, 주문전 보유수량:      0 주문수량:     24, 매매수량:     24, 주문후 보유수량:     24
# [2023-08-22] 종목: 004720, 주문전 보유수량:    856 주문수량:   -856, 매매수량:   -856, 주문후 보유수량:      0
# [2023-08-22] 종목: 011170, 주문전 보유수량:      7 주문수량:     -7, 매매수량:     -7, 주문후 보유수량:      0
# [2023-08-22] 종목: 016380, 주문전 보유수량:  7,368 주문수량: -7,368, 매매수량: -7,368, 주문후 보유수량:      0
# [2023-08-22] 종목: 016590, 주문전 보유수량:    335 주문수량:   -335, 매매수량:   -335, 주문후 보유수량:      0
# [2023-08-22] 종목: 028670, 주문전 보유수량:    245 주문수량:   -245, 매매수량:   -245, 주문후 보유수량:      0
# [2023-08-22] 종목: 044450, 주문전 보유수량:    156 주문수량:   -156, 매매수량:   -156, 주문후 보유수량:      0
# [2023-08-22] 종목: 145990, 주문전 보유수량:     24 주문수량:    -24, 매매수량:    -24, 주문후 보유수량:      0
# [2023-08-22] <KQuantNotAllowShort> 공매도 금지 오류: 매도 수량이 현재 보유수량보다 큼
# [2023-08-22] 종목: 214180, 주문전 보유수량:     98 주문수량:   -196, 매매수량:      0, 주문후 보유수량:     98
# [2023-08-22] 종목: 000210, 주문전 보유수량:      0 주문수량:     45, 매매수량:     45, 주문후 보유수량:     45
# [2023-08-22] 종목: 000590, 주문전 보유수량:      0 주문수량:     24, 매매수량:     24, 주문후 보유수량:     24
# [2023-08-22] 종목: 002320, 주문전 보유수량:      0 주문수량:     67, 매매수량:     67, 주문후 보유수량:     67
# [2023-08-22] 종목: 002900, 주문전 보유수량:      0 주문수량:    222, 매매수량:    222, 주문후 보유수량:    222
# [2023-08-22] 종목: 003960, 주문전 보유수량:      0 주문수량:     32, 매매수량:     32, 주문후 보유수량:     32
# [2023-08-22] 종목: 006200, 주문전 보유수량:      0 주문수량:  4,047, 매매수량:  4,047, 주문후 보유수량:  4,047
# [2023-08-22] 종목: 011370, 주문전 보유수량:      0 주문수량:  1,283, 매매수량:  1,283, 주문후 보유수량:  1,283
# [2023-08-22] 종목: 025530, 주문전 보유수량:      0 주문수량:    348, 매매수량:    348, 주문후 보유수량:    348
# [2023-08-22] 종목: 244920, 주문전 보유수량:      0 주문수량:    558, 매매수량:    558, 주문후 보유수량:    558
# [2023-08-23] 종목: 000210, 주문전 보유수량:     45 주문수량:    -45, 매매수량:    -45, 주문후 보유수량:      0
# [2023-08-23] 종목: 002320, 주문전 보유수량:     67 주문수량:    -67, 매매수량:    -67, 주문후 보유수량:      0
# [2023-08-23] 종목: 002900, 주문전 보유수량:    222 주문수량:   -222, 매매수량:   -222, 주문후 보유수량:      0
# [2023-08-23] 종목: 003960, 주문전 보유수량:     32 주문수량:    -32, 매매수량:    -32, 주문후 보유수량:      0
# [2023-08-23] 종목: 012620, 주문전 보유수량:    156 주문수량:   -156, 매매수량:   -156, 주문후 보유수량:      0
# [2023-08-23] 종목: 025530, 주문전 보유수량:    348 주문수량:   -348, 매매수량:   -348, 주문후 보유수량:      0
# [2023-08-23] 종목: 055550, 주문전 보유수량:    494 주문수량:   -494, 매매수량:   -494, 주문후 보유수량:      0
# [2023-08-23] 종목: 082850, 주문전 보유수량:    488 주문수량:   -488, 매매수량:   -488, 주문후 보유수량:      0
# [2023-08-23] <KQuantNotAllowShort> 공매도 금지 오류: 매도 수량이 현재 보유수량보다 큼
# [2023-08-23] 종목: 214180, 주문전 보유수량:     98 주문수량:   -196, 매매수량:      0, 주문후 보유수량:     98
# [2023-08-23] 종목: 227840, 주문전 보유수량:  1,497 주문수량: -1,497, 매매수량: -1,497, 주문후 보유수량:      0
# [2023-08-23] 종목: 244920, 주문전 보유수량:    558 주문수량:   -558, 매매수량:   -558, 주문후 보유수량:      0
# [2023-08-23] 종목: 001940, 주문전 보유수량:      0 주문수량:    560, 매매수량:    560, 주문후 보유수량:    560
# [2023-08-23] 종목: 014280, 주문전 보유수량:      0 주문수량:    462, 매매수량:    462, 주문후 보유수량:    462
# [2023-08-23] 종목: 024110, 주문전 보유수량:      0 주문수량:    720, 매매수량:    720, 주문후 보유수량:    720
# [2023-08-23] 종목: 050120, 주문전 보유수량:      0 주문수량:  1,595, 매매수량:  1,595, 주문후 보유수량:  1,595
# [2023-08-23] 종목: 053350, 주문전 보유수량:      0 주문수량:  1,174, 매매수량:  1,174, 주문후 보유수량:  1,174
# [2023-08-23] 종목: 072870, 주문전 보유수량:      0 주문수량:    334, 매매수량:    334, 주문후 보유수량:    334
# [2023-08-23] 종목: 205470, 주문전 보유수량:      0 주문수량:  1,956, 매매수량:  1,956, 주문후 보유수량:  1,956
# [2023-08-23] 종목: 383800, 주문전 보유수량:      0 주문수량:    406, 매매수량:    406, 주문후 보유수량:    406
# [2023-08-24] 종목: 005960, 주문전 보유수량:  3,315 주문수량: -3,315, 매매수량: -3,315, 주문후 보유수량:      0
# [2023-08-24] 종목: 013120, 주문전 보유수량:    287 주문수량:   -287, 매매수량:   -287, 주문후 보유수량:      0
# [2023-08-24] 종목: 053350, 주문전 보유수량:  1,174 주문수량: -1,174, 매매수량: -1,174, 주문후 보유수량:      0
# [2023-08-24] 종목: 072870, 주문전 보유수량:    334 주문수량:   -334, 매매수량:   -334, 주문후 보유수량:      0
# [2023-08-24] 종목: 205470, 주문전 보유수량:  1,956 주문수량: -1,956, 매매수량: -1,956, 주문후 보유수량:      0
# [2023-08-24] <KQuantNotAllowShort> 공매도 금지 오류: 매도 수량이 현재 보유수량보다 큼
# [2023-08-24] 종목: 214180, 주문전 보유수량:     98 주문수량:   -196, 매매수량:      0, 주문후 보유수량:     98
# [2023-08-24] 종목: 001290, 주문전 보유수량:      0 주문수량:  4,923, 매매수량:  4,923, 주문후 보유수량:  4,923
# [2023-08-24] 종목: 012620, 주문전 보유수량:      0 주문수량:    518, 매매수량:    518, 주문후 보유수량:    518
# [2023-08-24] 종목: 014830, 주문전 보유수량:      0 주문수량:     69, 매매수량:     69, 주문후 보유수량:     69
# [2023-08-24] 종목: 032560, 주문전 보유수량:      0 주문수량:    468, 매매수량:    468, 주문후 보유수량:    468
# [2023-08-24] 종목: 036460, 주문전 보유수량:      0 주문수량:    557, 매매수량:    557, 주문후 보유수량:    557
# [2023-08-24] 종목: 081580, 주문전 보유수량:      0 주문수량:  1,570, 매매수량:  1,570, 주문후 보유수량:  1,570
# [2023-08-24] 종목: 155660, 주문전 보유수량:      0 주문수량:  1,615, 매매수량:  1,615, 주문후 보유수량:  1,615
# [2023-08-24] 종목: 265520, 주문전 보유수량:      0 주문수량:    181, 매매수량:    181, 주문후 보유수량:    181
# [2023-08-25] 종목: 001290, 주문전 보유수량:  4,923 주문수량: -4,923, 매매수량: -4,923, 주문후 보유수량:      0
# [2023-08-25] 종목: 002310, 주문전 보유수량:     29 주문수량:    -29, 매매수량:    -29, 주문후 보유수량:      0
# [2023-08-25] 종목: 004170, 주문전 보유수량:      5 주문수량:     -5, 매매수량:     -5, 주문후 보유수량:      0
# [2023-08-25] 종목: 012620, 주문전 보유수량:    518 주문수량:   -518, 매매수량:   -518, 주문후 보유수량:      0
# [2023-08-25] 종목: 014280, 주문전 보유수량:    462 주문수량:   -462, 매매수량:   -462, 주문후 보유수량:      0
# [2023-08-25] 종목: 014830, 주문전 보유수량:     69 주문수량:    -69, 매매수량:    -69, 주문후 보유수량:      0
# [2023-08-25] 종목: 050120, 주문전 보유수량:  1,595 주문수량: -1,595, 매매수량: -1,595, 주문후 보유수량:      0
# [2023-08-25] 종목: 081580, 주문전 보유수량:  1,570 주문수량: -1,570, 매매수량: -1,570, 주문후 보유수량:      0
# [2023-08-25] <KQuantNotAllowShort> 공매도 금지 오류: 매도 수량이 현재 보유수량보다 큼
# [2023-08-25] 종목: 214180, 주문전 보유수량:     98 주문수량:   -196, 매매수량:      0, 주문후 보유수량:     98
# [2023-08-25] 종목: 265520, 주문전 보유수량:    181 주문수량:   -181, 매매수량:   -181, 주문후 보유수량:      0
# [2023-08-25] 종목: 363280, 주문전 보유수량:    905 주문수량:   -905, 매매수량:   -905, 주문후 보유수량:      0
# [2023-08-25] 종목: 383800, 주문전 보유수량:    406 주문수량:   -406, 매매수량:   -406, 주문후 보유수량:      0
# [2023-08-25] 종목: 000880, 주문전 보유수량:      0 주문수량:    617, 매매수량:    617, 주문후 보유수량:    617
# [2023-08-25] 종목: 004720, 주문전 보유수량:      0 주문수량:    715, 매매수량:    715, 주문후 보유수량:    715
# [2023-08-25] 종목: 004990, 주문전 보유수량:      0 주문수량:    101, 매매수량:    101, 주문후 보유수량:    101
# [2023-08-25] 종목: 036530, 주문전 보유수량:      0 주문수량:    453, 매매수량:    453, 주문후 보유수량:    453
# [2023-08-25] 종목: 057050, 주문전 보유수량:      0 주문수량:     63, 매매수량:     63, 주문후 보유수량:     63
# [2023-08-25] 종목: 084010, 주문전 보유수량:      0 주문수량:    211, 매매수량:    211, 주문후 보유수량:    211
# [2023-08-25] 종목: 377460, 주문전 보유수량:      0 주문수량:  1,097, 매매수량:  1,097, 주문후 보유수량:  1,097
# [2023-08-28] 종목: 004720, 주문전 보유수량:    715 주문수량:   -715, 매매수량:   -715, 주문후 보유수량:      0
# [2023-08-28] 종목: 004990, 주문전 보유수량:    101 주문수량:   -101, 매매수량:   -101, 주문후 보유수량:      0
# [2023-08-28] 종목: 057050, 주문전 보유수량:     63 주문수량:    -63, 매매수량:    -63, 주문후 보유수량:      0
# [2023-08-28] <KQuantNotAllowShort> 공매도 금지 오류: 매도 수량이 현재 보유수량보다 큼
# [2023-08-28] 종목: 214180, 주문전 보유수량:     98 주문수량:   -196, 매매수량:      0, 주문후 보유수량:     98
# [2023-08-28] 종목: 377460, 주문전 보유수량:  1,097 주문수량: -1,097, 매매수량: -1,097, 주문후 보유수량:      0
# [2023-08-28] 종목: 004840, 주문전 보유수량:      0 주문수량:    572, 매매수량:    572, 주문후 보유수량:    572
# [2023-08-28] 종목: 005090, 주문전 보유수량:      0 주문수량:     86, 매매수량:     86, 주문후 보유수량:     86
# [2023-08-28] 종목: 023590, 주문전 보유수량:      0 주문수량:    488, 매매수량:    488, 주문후 보유수량:    488
# [2023-08-28] 종목: 030210, 주문전 보유수량:      0 주문수량:  1,183, 매매수량:  1,183, 주문후 보유수량:  1,183
# [2023-08-28] 종목: 032190, 주문전 보유수량:      0 주문수량:  1,099, 매매수량:  1,099, 주문후 보유수량:  1,099
# [2023-08-28] 종목: 121440, 주문전 보유수량:      0 주문수량:    622, 매매수량:    622, 주문후 보유수량:    622
# [2023-08-28] 종목: 294870, 주문전 보유수량:      0 주문수량:    271, 매매수량:    271, 주문후 보유수량:    271
# [2023-08-29] 종목: 000590, 주문전 보유수량:     24 주문수량:    -24, 매매수량:    -24, 주문후 보유수량:      0
# [2023-08-29] 종목: 004840, 주문전 보유수량:    572 주문수량:   -572, 매매수량:   -572, 주문후 보유수량:      0
# [2023-08-29] 종목: 005090, 주문전 보유수량:     86 주문수량:    -86, 매매수량:    -86, 주문후 보유수량:      0
# [2023-08-29] 종목: 084010, 주문전 보유수량:    211 주문수량:   -211, 매매수량:   -211, 주문후 보유수량:      0
# [2023-08-29] <KQuantNotAllowShort> 공매도 금지 오류: 매도 수량이 현재 보유수량보다 큼
# [2023-08-29] 종목: 214180, 주문전 보유수량:     98 주문수량:   -196, 매매수량:      0, 주문후 보유수량:     98
# [2023-08-29] 종목: 294870, 주문전 보유수량:    271 주문수량:   -271, 매매수량:   -271, 주문후 보유수량:      0
# [2023-08-29] 종목: 003240, 주문전 보유수량:      0 주문수량:     12, 매매수량:     12, 주문후 보유수량:     12
# [2023-08-29] 종목: 004720, 주문전 보유수량:      0 주문수량:    727, 매매수량:    727, 주문후 보유수량:    727
# [2023-08-29] 종목: 009310, 주문전 보유수량:      0 주문수량:  3,903, 매매수량:  3,903, 주문후 보유수량:  3,903
# [2023-08-29] 종목: 011760, 주문전 보유수량:      0 주문수량:     91, 매매수량:     91, 주문후 보유수량:     91
# [2023-08-29] 종목: 014280, 주문전 보유수량:      0 주문수량:    279, 매매수량:    279, 주문후 보유수량:    279
# [2023-08-29] 종목: 020000, 주문전 보유수량:      0 주문수량:    198, 매매수량:    198, 주문후 보유수량:    198
# [2023-08-29] 종목: 023410, 주문전 보유수량:      0 주문수량:    666, 매매수량:    666, 주문후 보유수량:    666
# [2023-08-29] 종목: 091340, 주문전 보유수량:      0 주문수량:    831, 매매수량:    831, 주문후 보유수량:    831
# [2023-08-30] 종목: 001120, 주문전 보유수량:     47 주문수량:    -47, 매매수량:    -47, 주문후 보유수량:      0
# [2023-08-30] 종목: 003070, 주문전 보유수량:    158 주문수량:   -158, 매매수량:   -158, 주문후 보유수량:      0
# [2023-08-30] 종목: 004720, 주문전 보유수량:    727 주문수량:   -727, 매매수량:   -727, 주문후 보유수량:      0
# [2023-08-30] 종목: 011760, 주문전 보유수량:     91 주문수량:    -91, 매매수량:    -91, 주문후 보유수량:      0
# [2023-08-30] <KQuantNotAllowShort> 공매도 금지 오류: 매도 수량이 현재 보유수량보다 큼
# [2023-08-30] 종목: 014280, 주문전 보유수량:    279 주문수량:   -558, 매매수량:      0, 주문후 보유수량:    279
# [2023-08-30] 종목: 020000, 주문전 보유수량:    198 주문수량:   -198, 매매수량:   -198, 주문후 보유수량:      0
# [2023-08-30] 종목: 023410, 주문전 보유수량:    666 주문수량:   -666, 매매수량:   -666, 주문후 보유수량:      0
# [2023-08-30] 종목: 024070, 주문전 보유수량:  1,001 주문수량: -1,001, 매매수량: -1,001, 주문후 보유수량:      0
# [2023-08-30] <KQuantNotAllowShort> 공매도 금지 오류: 매도 수량이 현재 보유수량보다 큼
# [2023-08-30] 종목: 214180, 주문전 보유수량:     98 주문수량:   -196, 매매수량:      0, 주문후 보유수량:     98
# [2023-08-30] 종목: 000210, 주문전 보유수량:      0 주문수량:     62, 매매수량:     62, 주문후 보유수량:     62
# [2023-08-30] 종목: 001250, 주문전 보유수량:      0 주문수량:    728, 매매수량:    728, 주문후 보유수량:    728
# [2023-08-30] 종목: 008060, 주문전 보유수량:      0 주문수량:    961, 매매수량:    961, 주문후 보유수량:    961
# [2023-08-30] 종목: 011780, 주문전 보유수량:      0 주문수량:     13, 매매수량:     13, 주문후 보유수량:     13
# [2023-08-30] 종목: 045100, 주문전 보유수량:      0 주문수량:     78, 매매수량:     78, 주문후 보유수량:     78
# [2023-08-30] 종목: 052330, 주문전 보유수량:      0 주문수량:    177, 매매수량:    177, 주문후 보유수량:    177
# [2023-08-30] 종목: 079650, 주문전 보유수량:      0 주문수량:    823, 매매수량:    823, 주문후 보유수량:    823
# [2023-08-30] 종목: 100220, 주문전 보유수량:      0 주문수량:    287, 매매수량:    287, 주문후 보유수량:    287
# [2023-08-30] 종목: 294870, 주문전 보유수량:      0 주문수량:    172, 매매수량:    172, 주문후 보유수량:    172
# [2023-08-31] 종목: 000210, 주문전 보유수량:     62 주문수량:    -62, 매매수량:    -62, 주문후 보유수량:      0
# [2023-08-31] <KQuantNotAllowShort> 공매도 금지 오류: 매도 수량이 현재 보유수량보다 큼
# [2023-08-31] 종목: 001250, 주문전 보유수량:    728 주문수량: -1,456, 매매수량:      0, 주문후 보유수량:    728
# [2023-08-31] 종목: 001500, 주문전 보유수량:  9,638 주문수량: -9,638, 매매수량: -9,638, 주문후 보유수량:      0
# [2023-08-31] 종목: 009310, 주문전 보유수량:  3,903 주문수량: -3,903, 매매수량: -3,903, 주문후 보유수량:      0
# [2023-08-31] <KQuantNotAllowShort> 공매도 금지 오류: 매도 수량이 현재 보유수량보다 큼
# [2023-08-31] 종목: 011780, 주문전 보유수량:     13 주문수량:    -26, 매매수량:      0, 주문후 보유수량:     13
# [2023-08-31] <KQuantNotAllowShort> 공매도 금지 오류: 매도 수량이 현재 보유수량보다 큼
# [2023-08-31] 종목: 014280, 주문전 보유수량:    279 주문수량:   -558, 매매수량:      0, 주문후 보유수량:    279
# [2023-08-31] 종목: 024110, 주문전 보유수량:    720 주문수량:   -720, 매매수량:   -720, 주문후 보유수량:      0
# [2023-08-31] 종목: 032560, 주문전 보유수량:    468 주문수량:   -468, 매매수량:   -468, 주문후 보유수량:      0
# [2023-08-31] <KQuantNotAllowShort> 공매도 금지 오류: 매도 수량이 현재 보유수량보다 큼
# [2023-08-31] 종목: 045100, 주문전 보유수량:     78 주문수량:   -156, 매매수량:      0, 주문후 보유수량:     78
# [2023-08-31] <KQuantNotAllowShort> 공매도 금지 오류: 매도 수량이 현재 보유수량보다 큼
# [2023-08-31] 종목: 052330, 주문전 보유수량:    177 주문수량:   -354, 매매수량:      0, 주문후 보유수량:    177
# [2023-08-31] 종목: 079650, 주문전 보유수량:    823 주문수량:   -823, 매매수량:   -823, 주문후 보유수량:      0
# [2023-08-31] 종목: 140520, 주문전 보유수량:  2,660 주문수량: -2,660, 매매수량: -2,660, 주문후 보유수량:      0
# [2023-08-31] 종목: 155660, 주문전 보유수량:  1,615 주문수량: -1,615, 매매수량: -1,615, 주문후 보유수량:      0
# [2023-08-31] <KQuantNotAllowShort> 공매도 금지 오류: 매도 수량이 현재 보유수량보다 큼
# [2023-08-31] 종목: 175330, 주문전 보유수량:    621 주문수량: -1,242, 매매수량:      0, 주문후 보유수량:    621
# [2023-08-31] <KQuantNotAllowShort> 공매도 금지 오류: 매도 수량이 현재 보유수량보다 큼
# [2023-08-31] 종목: 214180, 주문전 보유수량:     98 주문수량:   -196, 매매수량:      0, 주문후 보유수량:     98
# [2023-08-31] 종목: 294870, 주문전 보유수량:    172 주문수량:   -172, 매매수량:   -172, 주문후 보유수량:      0
# [2023-08-31] 종목: 001130, 주문전 보유수량:      0 주문수량:     20, 매매수량:     20, 주문후 보유수량:     20
# [2023-08-31] 종목: 005990, 주문전 보유수량:      0 주문수량:    289, 매매수량:    289, 주문후 보유수량:    289
# [2023-08-31] 종목: 017650, 주문전 보유수량:      0 주문수량:    196, 매매수량:    196, 주문후 보유수량:    196
# [2023-08-31] 종목: 039020, 주문전 보유수량:      0 주문수량:    667, 매매수량:    667, 주문후 보유수량:    667
# [2023-08-31] 종목: 092790, 주문전 보유수량:      0 주문수량:    289, 매매수량:    289, 주문후 보유수량:    289
# [2023-08-31] 종목: 137940, 주문전 보유수량:      0 주문수량:  3,644, 매매수량:  3,644, 주문후 보유수량:  3,644
# [2023-08-31] 종목: 225590, 주문전 보유수량:      0 주문수량:    937, 매매수량:    937, 주문후 보유수량:    937
# [2023-08-31] 종목: 267250, 주문전 보유수량:      0 주문수량:     77, 매매수량:     77, 주문후 보유수량:     77

# %%
dict_df_result['TOTAL']['TOTAL_VALUE'].tail(1)
# Out:
# 21    989,106,460
# Name: TOTAL_VALUE, dtype: int64
