# %%
CFG = {
    "buying_order_n": 8,
    "selling_order_percentage": 40,
    "sampling_size": 200,
}

# %%
import datetime as dt
import random

import numpy as np
import pandas as pd
from tqdm import tqdm

import kquant as kq


# API_account
def set_api_account():
    kq.set_api("KRX2308020", "EQDkUcyI3dK6oIAXqAR8BXOK4bKxHHmH")
    return None

set_api_account()

# %%
class STATUS_LOADER:
    """
    STATUS_LOADER : 상태 정보 추출 클래스
    """

    def __init__(self, dict_df_result: dict, dict_df_position: dict) -> None:
        """
        STATUS_LOADER의 생성자

        :param dict dict_df_result: dict_df_result 입니다.
        :param dict dict_df_position: dict_df_position 입니다.
        :return: None
        :rtype: None
        """
        self.dict_df_result = dict_df_result
        self.dict_df_position = dict_df_position

    def get_current_cash(self) -> float:
        """
        현재 보유 cash를 반환하는 메서드

        :return : 현재 보유 cash
        :rtype: float
        """
        _dict_df_result = self.dict_df_result
        try:
            _df_result_total = _dict_df_result["TOTAL"]
            _current_cash = (
                _df_result_total.sort_values("DATE").tail(1)["CASH"].values[0]
            )
            return _current_cash
        except:
            return 1_000_000_000.0

    def get_status_df(self) -> pd.DataFrame:
        """
        현재 보유 position 관련 정보를 반환하는 메서드

        :return: 보유한 symbol, 갯수, 구매가격, 현재 가격을 데이터프레임 형태로 가져옵니다.
        :rtype: pd.DataFrame
        """
        current_symbol_list = list()
        _dict_df_result = self.dict_df_result
        _dict_df_position = self.dict_df_position

        _total_symbols = sorted(_dict_df_position.keys())

        for _symbol in _total_symbols:
            try:
                _symbol_result_df = _dict_df_result[_symbol]
                _symbol_position_df = _dict_df_position[_symbol]

                _current_price = (
                    _symbol_result_df.sort_values("DATE").tail(1)["PRICE"].values[0]
                )
                _trade_price = _symbol_position_df["TRADE_PRICE"].values[0]
                _current_qty = _symbol_position_df["QTY"].values[0]

                current_symbol_list.append(
                    {
                        "SYMBOL": _symbol,
                        "CURRENT_QTY": _current_qty,
                        "CURRENT_PRICE": _current_price,
                        "TRADE_PRICE": _trade_price,
                    }
                )
            except:
                pass
        return pd.DataFrame(
            current_symbol_list,
            columns=["SYMBOL", "CURRENT_QTY", "CURRENT_PRICE", "TRADE_PRICE"],
        )

# %%
class SYMBOL_LOADER:
    """
    SYMBOL_LOADER : 거래가능한 주식 symbol을 필터-추출하는 클래스
    """

    @staticmethod
    def load_symbols_df() -> pd.DataFrame:
        """
        한국거래소 종목 목록 데이터프레임을 호출하는 메서드

        :return : 한국거래소 종목 목록 데이터프레임
        :rtype : pd.DataFrame
        """
        symbols_df = kq.symbol_stock()
        return symbols_df

    class SYMBOL_FILTER:
        """
        SYMBOl_FILTER : symbols를 filtering 하는 클래스
        """

        @staticmethod
        def filter__market(symbols_df: pd.DataFrame) -> pd.DataFrame:
            """
            market에 대한 필터링을 진행하는 메서드

            :param pd.DataFrame : symbols_df : 한국거래소 종목 목록 데이터프레임
            :return: MARKET이 [코스닥, 유가증권]에 속하는 데이터프레임
            :rtype: pd.DataFrame
            """
            filtered_symbols_df = symbols_df[
                (symbols_df["MARKET"].isin(["코스닥", "유가증권"]))
            ].copy()
            return filtered_symbols_df

        @staticmethod
        def filter__admin_issue(symbols_df: pd.DataFrame) -> pd.DataFrame:
            """
            ADMIN_ISSUE에 대한 필터링을 진행하는 메서드

            :param pd.DataFrame : symbols_df : 한국거래소 종목 목록 데이터프레임
            :return: ADMIN_ISSUE가 0인 데이터프레임
            :rtype: pd.DataFrame
            """
            filtered_symbols_df = symbols_df[(symbols_df["ADMIN_ISSUE"] == 0)].copy()
            return filtered_symbols_df

        @staticmethod
        def filter_sec_type(symbols_df: pd.DataFrame) -> pd.DataFrame:
            """
            SEC_TYPE에 대한 필터링을 진행하는 메서드

            :param pd.DataFrame : symbols_df : 한국거래소 종목 목록 데이터프레임
            :return: SEC_TYPE이 [ST, EF, EN]에 속하는 데이터프레임
            :rtype: pd.DataFrame
            """
            filtered_symbols_df = symbols_df[
                symbols_df["SEC_TYPE"].isin(["ST", "EF", "EN"])
            ].copy()
            return filtered_symbols_df

    def filter_symbols_df(self, symbols_df: pd.DataFrame) -> pd.DataFrame:
        """
        symbol_df 에 대한 필터링을 진행하는 메서드

        :param pd.DataFrame : symbols_df : 한국거래소 종목 목록 데이터프레임
        :return: SYMBOL_FILTER의 메서드를 거친 데이터프레임
        :rtype: pd.DataFrame
        """
        symbol_filter = self.SYMBOL_FILTER()
        filtered_symbols_df = symbol_filter.filter__market(symbols_df)
        filtered_symbols_df = symbol_filter.filter__admin_issue(filtered_symbols_df)
        filtered_symbols_df = symbol_filter.filter_sec_type(filtered_symbols_df)
        return filtered_symbols_df

    @staticmethod
    def get_symbols(symbols_df: pd.DataFrame) -> list:
        """
        symbols_df의 symbol을 중복을 제거하여 추출하는 메서드

        :param pd.DataFrame : symbols_df : 한국거래소 종목 목록 데이터프레임
        :return: symbols
        :rtype: list
        """
        symbols = sorted(set(symbols_df["SYMBOL"]))
        return symbols

    # SYMBOL_LOADER PIPELINE
    def __call__(self) -> list:
        """
        SYMBOL_LOADER의 파이프라인을 제공하는 메서드

        :return: 필터를 거친 symbols
        :rtype: list
        """
        symbols_df = self.load_symbols_df()
        filtered_symbols_df = self.filter_symbols_df(symbols_df)
        symbols = self.get_symbols(filtered_symbols_df)
        return symbols

# %%
class FUNDAMENTAL_LOADER:
    """
    FUNDAMENTAL_LOADER : fundamental_analysis를 위한 정보를 추출하는 클래스
    """

    def __init__(self, symbol: str, date: dt.date) -> None:
        """
        FUNDAMENTAL_LOADER의 생성자

        :param str symbol: stock의 symbol 입니다.
        :param datetime.date date: 현재 날짜 입니다.

        :attr : pd.DataFrmae daily_stock_df : 현재 날짜 기준 가장 최근 stock데이터 입니다.
        """
        self.symbol = symbol
        self.date = date
        self.daily_stock_df = kq.daily_stock(
            symbol,
            start_date=date - dt.timedelta(days=7),
            end_date=date,
        )

    def load_recent_close(self) -> float:
        """
        가장 최근 종가를 추출합니다.
        :return: 종가
        :rtype: float
        """
        daily_stock_df = self.daily_stock_df
        _close = daily_stock_df.sort_values("DATE").tail(1)["CLOSE"].values[0]
        return _close

    def load_recent_marketcap(self) -> float:
        """
        가장 최근 시가총액을 추출합니다.

        :return: 시가총액
        :rtype: float
        """
        daily_stock_df = self.daily_stock_df
        _marketcap = daily_stock_df.sort_values("DATE").tail(1)["MARKETCAP"].values[0]
        return float(_marketcap)

    def load_recent_netprofit(self) -> float:
        """
        공시자료 중 가장 최근 당기순이익을 추출합니다.

        :return: 당기순이익
        :rtype: float
        """
        netprofit_df = kq.account_history(self.symbol, "122700")
        netprofit_df.sort_values("YEARMONTH", inplace=True)
        _netprofit = netprofit_df.tail(1)["VALUE"].values[0] * 1000
        return float(_netprofit)

    def load_recent_assets(self) -> float:
        """
        공시자료 중 가장 최근 총 자산를 추출합니다.

        :return: 총 자산
        :rtype: float
        """
        assets_df = kq.account_history(self.symbol, "111000")
        assets_df.sort_values("YEARMONTH", inplace=True)
        _assets = assets_df.tail(1)["VALUE"].values[0] * 1000
        return float(_assets)

    def load_recent_current_assets(self) -> float:
        """
        공시자료 중 가장 최근 유동 자산를 추출합니다.

        :return: 유동 자산
        :rtype: float
        """
        current_assets_df = kq.account_history(self.symbol, "111100")
        current_assets_df.sort_values("YEARMONTH", inplace=True)
        _current_assets = current_assets_df.tail(1)["VALUE"].values[0] * 1000
        return float(_current_assets)

    def load_recent_liabilities(self) -> float:
        """
        공시자료 중 가장 최근 총 부채를 추출합니다.

        :return: 총 부채
        :rtype: float
        """
        liabilities_df = kq.account_history(self.symbol, "113000")
        liabilities_df.sort_values("YEARMONTH", inplace=True)
        _liabilities = liabilities_df.tail(1)["VALUE"].values[0] * 1000
        return float(_liabilities)

    def load_recent_equity(self) -> float:
        """
        공시자료 중 가장 최근 총 자본(총 자산 - 총 부채)를 추출합니다.

        :return: 총 자본(총 자산 - 총 부채)
        :rtype: float
        """
        equity_df = kq.account_history(self.symbol, "115000")
        equity_df.sort_values("YEARMONTH", inplace=True)
        _equity = equity_df.tail(1)["VALUE"].values[0] * 1000
        return float(_equity)

    def load_recent_EBITDA(self) -> float:
        """
        공시자료 중 가장 최근 EBITDA를 추출합니다.

        :return: EBITDA
        :rtype: float
        """
        ebitda_df = kq.account_history(self.symbol, "123000")
        ebitda_df.sort_values("YEARMONTH", inplace=True)
        _ebitda = ebitda_df.tail(1)["VALUE"].values[0] * 1000
        return float(_ebitda)

    def __call__(self) -> dict:
        """
        fundmanetal analysis를 위해 필요한 데이터를 가져와서 dictionary를 반환한다.

        :return: fundamental analysis를 위한 데이터 dictionary
        :rtype: dict
        """
        _close = self.load_recent_close()
        _marketcap = self.load_recent_marketcap()
        _netprofit = self.load_recent_netprofit()
        _assets = self.load_recent_assets()
        _current_assets = self.load_recent_current_assets()
        _liabilities = self.load_recent_liabilities()
        _equity = self.load_recent_equity()
        _ebitda = self.load_recent_EBITDA()
        return {
            "SYMBOL": self.symbol,
            "CLOSE": _close,
            "MARKETCAP": _marketcap,
            "NETPROFIT": _netprofit,
            "ASSETS": _assets,
            "CURRENT_ASSETS": _current_assets,
            "LIABILITIES": _liabilities,
            "EQUITY": _equity,
            "EBITDA": _ebitda,
        }

# %%
class PBR_PROCESSOR:
    """
    PBR_PROCESSOR : PBR에 대한 정보를 SCORE로 정제하여 반환하는 클래스
    """
    def __init__(self, fundamental_df) -> None:
        self.fundamental_df = fundamental_df

    @staticmethod
    def append_pbr(fundamental_df):
        fundamental_df["PBR"] = fundamental_df["MARKETCAP"] / (
            fundamental_df["EQUITY"]
        )
        return fundamental_df

    @staticmethod
    def filter_negative_pbr(fundamental_df):
        fundamental_df = fundamental_df[fundamental_df["PBR"] > 0]
        return fundamental_df

    @staticmethod
    def append_score(fundamental_df: pd.DataFrame) -> pd.DataFrame:
        fundamental_df["PBR_SCORE"] = fundamental_df["PBR"].sum() / fundamental_df["PBR"]
        return fundamental_df

    def __call__(self):
        fundamental_df = self.fundamental_df

        fundamental_df = self.append_pbr(fundamental_df)
        fundamental_df = self.filter_negative_pbr(fundamental_df)
        fundamental_df = self.append_score(fundamental_df)

        score_df = fundamental_df.loc[:, ["SYMBOL", "PBR_SCORE"]]
        return score_df

# %%
class PER_PROCESSOR:
    """
    PBR_PROCESSOR : PBR에 대한 정보를 SCORE로 정제하여 반환하는 클래스
    """
    def __init__(self, fundamental_df) -> None:
        self.fundamental_df = fundamental_df

    @staticmethod
    def append_per(fundamental_df):
        fundamental_df["PER"] = fundamental_df["MARKETCAP"] / (
            fundamental_df["NETPROFIT"]
        )
        return fundamental_df

    @staticmethod
    def filter_negative_per(fundamental_df):
        fundamental_df = fundamental_df[fundamental_df["PER"] > 0]
        return fundamental_df

    @staticmethod
    def append_score(fundamental_df: pd.DataFrame) -> pd.DataFrame:
        fundamental_df["PER_SCORE"] = fundamental_df["PER"].sum() / fundamental_df["PER"]
        return fundamental_df

    def __call__(self):
        fundamental_df = self.fundamental_df

        fundamental_df = self.append_per(fundamental_df)
        fundamental_df = self.filter_negative_per(fundamental_df)
        fundamental_df = self.append_score(fundamental_df)

        score_df = fundamental_df.loc[:, ["SYMBOL", "PER_SCORE"]]
        return score_df

# %%
class ROE_PROCESSOR:
    """
    ROE_PROCESSOR : ROE에 대한 정보를 SCORE로 정제하여 반환하는 클래스
    """

    def __init__(self, fundamental_df) -> None:
        self.fundamental_df = fundamental_df

    @staticmethod
    def append_roe(fundamental_df):
        fundamental_df["ROE"] = fundamental_df["NETPROFIT"] / (fundamental_df["ASSETS"])
        return fundamental_df

    @staticmethod
    def filter_negative_roe(fundamental_df):
        fundamental_df = fundamental_df[fundamental_df["ROE"] > 0]
        return fundamental_df

    @staticmethod
    def append_score(fundamental_df: pd.DataFrame) -> pd.DataFrame:
        fundamental_df["ROE_SCORE"] = fundamental_df["ROE"] / fundamental_df["ROE"].sum()
        return fundamental_df

    def __call__(self):
        fundamental_df = self.fundamental_df

        fundamental_df = self.append_roe(fundamental_df)
        fundamental_df = self.filter_negative_roe(fundamental_df)
        fundamental_df = self.append_score(fundamental_df)

        score_df = fundamental_df.loc[:, ["SYMBOL", "ROE_SCORE"]]
        return score_df

# %%
class EV_EBITDA_PROCESSOR:
    """
    EV_EBITDA_PROCESSOR : EV_EBITDA에 대한 정보를 SCORE로 정제하여 반환하는 클래스
    """

    def __init__(self, fundamental_df) -> None:
        self.fundamental_df = fundamental_df

    @staticmethod
    def append_ev_ebitda(fundamental_df):
        fundamental_df["EV_EBITDA"] = (
            fundamental_df["MARKETCAP"]
            + (fundamental_df["LIABILITIES"] - fundamental_df["CURRENT_ASSETS"])
        ) / (fundamental_df["EBITDA"])
        return fundamental_df

    @staticmethod
    def filter_negative_ev_ebitda(fundamental_df):
        fundamental_df = fundamental_df[fundamental_df["EV_EBITDA"] > 0]
        return fundamental_df

    @staticmethod
    def append_score(fundamental_df: pd.DataFrame) -> pd.DataFrame:
        fundamental_df["EV_EBITDA_SCORE"] = (
            fundamental_df["EV_EBITDA"].sum() / fundamental_df["EV_EBITDA"]
        )
        return fundamental_df

    def __call__(self):
        fundamental_df = self.fundamental_df

        fundamental_df = self.append_ev_ebitda(fundamental_df)
        fundamental_df = self.filter_negative_ev_ebitda(fundamental_df)
        fundamental_df = self.append_score(fundamental_df)

        score_df = fundamental_df.loc[:, ["SYMBOL", "EV_EBITDA_SCORE"]]
        return score_df

# %%
class BUYING_ORDER_PROCESSOR:
    """
    BUYING_ORDER_PROCESSOR : 매수주문을 생성하는 클래스
    """
    def __init__(self, score_df, invest_money, status_df, n) -> None:
        """
        BUYING_ORDER_PROCESSOR의 생성자
        
        :param pd.DataFrame score_df: symbol,score,close를 가진 데이터프레임
        :param float invest_money: 당일 활용 투자 금액
        :param pd.DataFrame status_df: 현재 position과 관련된 정보를 가진 데이터프레임
        :param int n: 당일 투자종목의 갯수
        """
        self.score_df = score_df
        self.invest_money = invest_money
        self.status_df = status_df
        self.n = n

    @staticmethod
    def filter_positioned_symbol(score_df, positioned_symbol):
        """
        이미 position이 있는 종목을 필터링 하는 메소드
        
        :param pd.DataFrame score_df: symbol,score,close를 가진 데이터프레임
        :param list positioned_symbol: 현재 이미 position이 있는 symbol의 리스트
        """
        filtered_score_df = score_df[~(score_df["SYMBOL"].isin(positioned_symbol))]
        return filtered_score_df

    @staticmethod
    def get_high_score_df(score_df, n):
        """
        score_df의 상위 n개의 row를 추출하는 메서드
        
        :param pd.DataFrame score_df: symbol,score,close를 가진 데이터프레임
        :param int n: 당일 투자종목의 갯수
        """
        high_score_df = score_df.nlargest(n, "SCORE")
        return high_score_df

    @staticmethod
    def append_price_invest(high_score_df, invest_money):
        """
        당일 활용 투자 금액을 score 기준으로 분배한 column을 생성하는 메서드
        
        :param pd.DataFrame high_score_df: score_df의 score 상위 데이터프레임
        :param float invest_money: 당일 활용 투자 금액
        """
        high_score_df["PRICE_INVEST"] = (
            high_score_df["SCORE"] / high_score_df["SCORE"].sum()
        ) * invest_money
        return high_score_df

    @staticmethod
    def append_cnt_invest(high_score_df: pd.DataFrame) -> pd.DataFrame:
        """
        당일 활용 투자 금액 최근 종가로 나누어 주문 갯수를 column으로 생성하는 메서드
        
        :param pd.DataFrame high_score_df: score_df의 score 상위 데이터프레임
        """
        high_score_df["CNT_INVEST"] = (
            high_score_df["PRICE_INVEST"] // high_score_df["CLOSE"]
        )
        return high_score_df

    @staticmethod
    def get_order_from_df(df):
        """
        데이터 프레임에서 signiture에 맞게 주문 list를 추출하는 메서드
        
        :param pd.DataFrame df: [SYMBOL,CNT_INVEST]를 가진 데이터프레임
        """
        orders = list(
            df.set_index("SYMBOL")["CNT_INVEST"].astype(int).to_dict().items()
        )
        return orders

    def __call__(self) -> list:
        """
        BUYING_ORDER_PROCESSOR의 pipeline을 진행하는 메서드
        
        """
        score_df = self.score_df
        invest_money = self.invest_money
        status_df = self.status_df
        n = self.n
        
        positioned_symbol = sorted(set(status_df["SYMBOL"]))
        filtered_positioned_df = self.filter_positioned_symbol(
            score_df, positioned_symbol
        )

        high_score_df = self.get_high_score_df(filtered_positioned_df, n)
        high_score_df = self.append_price_invest(high_score_df, invest_money)
        high_score_df = self.append_cnt_invest(high_score_df)
        buying_order = self.get_order_from_df(high_score_df)
        return buying_order

# %%
class SELLING_ORDER_PROCESSOR:
    """
    SELLING_ORDER_PROCESSOR : 매도주문을 추출하는 클래스
    """

    def __init__(self, score_df, status_df, percentage) -> None:
        """
        SELLING_ORDER_PROCESSOR의 생성자

        :param pd.DataFrame score_df: symbol,score,close를 가진 데이터프레임
        :param pd.DataFrame status_df: 현재 position과 관련된 정보를 가진 데이터프레임
        :param int percentage: low_score를 선정하기 위한 하위 (n-percent)의 기준
        """
        self.score_df = score_df
        self.status_df = status_df
        self.percentage = percentage

    @staticmethod
    def get_limit_line(score_df, percentage):
        """
        score 하위 [percentage]% 를 한계선으로 설정하고 이를 기준값을 추출

        :param pd.DataFrame score_df: symbol,score,close를 가진 데이터프레임
        :param int percentage: low_score를 선정하기 위한 하위 (n-percent)의 기준
        """
        limit_line = np.percentile(score_df["SCORE"], percentage)
        return limit_line

    @staticmethod
    def get_low_score_df(score_df: pd.DataFrame, limit_line: float) -> pd.DataFrame:
        """
        기준값을 바탕으로 low_score_df를 추출하는 메서드

        :param pd.DataFrame score_df: symbol,score,close를 가진 데이터프레임
        :param float limit_line: get_limit_line에서 추출한 하위 한계선
        """
        low_score_df = score_df[score_df["SCORE"] < limit_line]
        return low_score_df

    @staticmethod
    def get_filtered_position_symbols(
        low_score_df: pd.DataFrame, position_symbols: list
    ) -> pd.DataFrame:
        """
        low_score_df 중 position_symbol에 속하는 symbol만 추출하는 메서드

        :param pd.DataFrame low_score_df: symbol,score,close를 가진 데이터프레임
        :param list position_symbols: 현재 이미 position이 있는 symbol의 리스트
        """
        filtered_position_symbols = sorted(
            set(low_score_df["SYMBOL"]) & set(position_symbols)
        )
        return filtered_position_symbols

    @staticmethod
    def get_order_from_df(df):
        """
        데이터 프레임에서 signiture에 맞게 주문 list를 추출하는 메서드

        :param pd.DataFrame df: [SYMBOL,CURRENT_QTY]를 가진 데이터프레임
        """
        orders = list(
            df.set_index("SYMBOL")["CURRENT_QTY"]
            .apply(lambda x: x * -1)
            .astype(int)
            .to_dict()
            .items()
        )
        return orders

    def __call__(self) -> list:
        """
        SELLING_ORDER_PROCESSOR의 pipeline을 진행하는 메서드
        """
        score_df = self.score_df
        status_df = self.status_df
        percentage = self.percentage
        position_symbols = sorted(set(status_df["SYMBOL"]))

        limit_line = self.get_limit_line(score_df, percentage)
        low_score_df = self.get_low_score_df(score_df, limit_line)
        filtered_position_symbols = self.get_filtered_position_symbols(
            low_score_df, position_symbols
        )

        selling_df = status_df[status_df["SYMBOL"].isin(filtered_position_symbols)]
        selling_orders = self.get_order_from_df(selling_df)

        return selling_orders

# %%
import random
import logging
import datetime as dt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

mms = MinMaxScaler()


def trade_func_tot(
    date: dt.date,
    dict_df_result: dict[str, pd.DataFrame],
    dict_df_position: dict[str, pd.DataFrame],
    logger: logging.Logger,
) -> list[tuple[str, int]]:
    try:
        """
        STATUS_LOADER
        """
        status_loader = STATUS_LOADER(dict_df_result, dict_df_position)

        current_cash = status_loader.get_current_cash()
        invest_money = current_cash * 0.75

        status_df = status_loader.get_status_df()
        position_symbols = sorted(set(status_df["SYMBOL"]))

        """
        SYMBOL_LOADER
        """
        symbol_loader = SYMBOL_LOADER()
        total_symbols = symbol_loader()

        sampled_symbols = random.sample(total_symbols, CFG["sampling_size"])
        using_symbols = sorted(set(sampled_symbols + position_symbols))

        """
        FUNDAMENTAL_LOADER
        """
        fundamental_data_list = list()
        for symbol in using_symbols:
            try:
                _fundamental_loader = FUNDAMENTAL_LOADER(symbol, date)
                _fundamental_data = _fundamental_loader()
                fundamental_data_list.append(_fundamental_data)
            except:
                pass
        fundamental_df = pd.DataFrame(fundamental_data_list)
        symbol_close_dict = fundamental_df.set_index("SYMBOL")["CLOSE"].to_dict()
        
        """
        PBR_PROCESSOR
        """
        pbr_processor = PBR_PROCESSOR(fundamental_df)
        pbr_score_df = pbr_processor()
        """
        PER_PROCESSOR
        """
        per_processor = PER_PROCESSOR(fundamental_df)
        per_score_df = per_processor()
        """
        ROE_PROCESSOR
        """
        roe_processor = ROE_PROCESSOR(fundamental_df)
        roe_score_df = roe_processor()
        """
        EV_EBITDA_PROCESSOR
        """
        ev_ebitda_processor = EV_EBITDA_PROCESSOR(fundamental_df)
        ev_ebitda_score_df = ev_ebitda_processor()
        score_df = (
            pbr_score_df.merge(per_score_df.loc[:, ["SYMBOL", "PER_SCORE"]], on="SYMBOL")
            .merge(roe_score_df.loc[:, ["SYMBOL", "ROE_SCORE"]], on="SYMBOL")
            .merge(ev_ebitda_score_df.loc[:, ["SYMBOL", "EV_EBITDA_SCORE"]], on="SYMBOL")
        )
        score_df.dropna(inplace=True)
        score_df.iloc[:, 1:] = mms.fit_transform(score_df.iloc[:, 1:])
        
        score_df["SCORE"] = (
            score_df["PBR_SCORE"] * 1
            + score_df["PER_SCORE"] * 1
            + score_df["ROE_SCORE"] * 1
            + score_df["EV_EBITDA_SCORE"] * 1
        )

        score_df["CLOSE"] = score_df["SYMBOL"].map(symbol_close_dict)

        """
        BUYING_ORDER_PROCESSOR
        """
        buying_order_processor = BUYING_ORDER_PROCESSOR(
            score_df, invest_money, status_df, CFG["buying_order_n"]
        )
        buying_orders = buying_order_processor()

        """
        SELLING_ORDER_PROCESSOR
        """
        selling_order_processor = SELLING_ORDER_PROCESSOR(
            score_df, status_df, CFG["selling_order_percentage"]
        )
        selling_orders = selling_order_processor()

        symbols_and_orders = buying_orders + selling_orders
        return symbols_and_orders
    except:
        return []

# %%
def trade_func_pbr(
    date: dt.date,
    dict_df_result: dict[str, pd.DataFrame],
    dict_df_position: dict[str, pd.DataFrame],
    logger: logging.Logger,
) -> list[tuple[str, int]]:
    try:
        """
        STATUS_LOADER
        """
        status_loader = STATUS_LOADER(dict_df_result, dict_df_position)

        current_cash = status_loader.get_current_cash()
        invest_money = current_cash * 0.75

        status_df = status_loader.get_status_df()
        position_symbols = sorted(set(status_df["SYMBOL"]))

        """
        SYMBOL_LOADER
        """
        symbol_loader = SYMBOL_LOADER()
        total_symbols = symbol_loader()

        sampled_symbols = random.sample(total_symbols, CFG["sampling_size"])
        using_symbols = sorted(set(sampled_symbols + position_symbols))

        """
        FUNDAMENTAL_LOADER
        """
        fundamental_data_list = list()
        for symbol in tqdm(using_symbols):
            try:
                _fundamental_loader = FUNDAMENTAL_LOADER(symbol, date)
                _fundamental_data = _fundamental_loader()
                fundamental_data_list.append(_fundamental_data)
            except:
                pass
        fundamental_df = pd.DataFrame(fundamental_data_list)
        symbol_close_dict = fundamental_df.set_index("SYMBOL")["CLOSE"].to_dict()
        
        """
        PBR_PROCESSOR
        """
        pbr_processor = PBR_PROCESSOR(fundamental_df)
        pbr_score_df = pbr_processor()
        """
        PER_PROCESSOR
        """
        per_processor = PER_PROCESSOR(fundamental_df)
        per_score_df = per_processor()
        """
        ROE_PROCESSOR
        """
        roe_processor = ROE_PROCESSOR(fundamental_df)
        roe_score_df = roe_processor()
        """
        EV_EBITDA_PROCESSOR
        """
        ev_ebitda_processor = EV_EBITDA_PROCESSOR(fundamental_df)
        ev_ebitda_score_df = ev_ebitda_processor()
        score_df = (
            pbr_score_df.merge(per_score_df.loc[:, ["SYMBOL", "PER_SCORE"]], on="SYMBOL")
            .merge(roe_score_df.loc[:, ["SYMBOL", "ROE_SCORE"]], on="SYMBOL")
            .merge(ev_ebitda_score_df.loc[:, ["SYMBOL", "EV_EBITDA_SCORE"]], on="SYMBOL")
        )
        score_df.dropna(inplace=True)
        score_df.iloc[:, 1:] = mms.fit_transform(score_df.iloc[:, 1:])
        
        score_df["SCORE"] = (
            score_df["PBR_SCORE"] * 1
            + score_df["PER_SCORE"] * 0
            + score_df["ROE_SCORE"] * 0
            + score_df["EV_EBITDA_SCORE"] * 0
        )

        score_df["CLOSE"] = score_df["SYMBOL"].map(symbol_close_dict)

        """
        BUYING_ORDER_PROCESSOR
        """
        buying_order_processor = BUYING_ORDER_PROCESSOR(
            score_df, invest_money, status_df, CFG["buying_order_n"]
        )
        buying_orders = buying_order_processor()

        """
        SELLING_ORDER_PROCESSOR
        """
        selling_order_processor = SELLING_ORDER_PROCESSOR(
            score_df, status_df, CFG["selling_order_percentage"]
        )
        selling_orders = selling_order_processor()

        symbols_and_orders = buying_orders + selling_orders
        return symbols_and_orders
    except:
        return []

# %%
def trade_func_per(
    date: dt.date,
    dict_df_result: dict[str, pd.DataFrame],
    dict_df_position: dict[str, pd.DataFrame],
    logger: logging.Logger,
) -> list[tuple[str, int]]:
    try:
        """
        STATUS_LOADER
        """
        status_loader = STATUS_LOADER(dict_df_result, dict_df_position)

        current_cash = status_loader.get_current_cash()
        invest_money = current_cash * 0.75

        status_df = status_loader.get_status_df()
        position_symbols = sorted(set(status_df["SYMBOL"]))

        """
        SYMBOL_LOADER
        """
        symbol_loader = SYMBOL_LOADER()
        total_symbols = symbol_loader()

        sampled_symbols = random.sample(total_symbols, CFG["sampling_size"])
        using_symbols = sorted(set(sampled_symbols + position_symbols))

        """
        FUNDAMENTAL_LOADER
        """
        fundamental_data_list = list()
        for symbol in using_symbols:
            try:
                _fundamental_loader = FUNDAMENTAL_LOADER(symbol, date)
                _fundamental_data = _fundamental_loader()
                fundamental_data_list.append(_fundamental_data)
            except:
                pass
        fundamental_df = pd.DataFrame(fundamental_data_list)
        symbol_close_dict = fundamental_df.set_index("SYMBOL")["CLOSE"].to_dict()
        
        """
        PBR_PROCESSOR
        """
        pbr_processor = PBR_PROCESSOR(fundamental_df)
        pbr_score_df = pbr_processor()
        """
        PER_PROCESSOR
        """
        per_processor = PER_PROCESSOR(fundamental_df)
        per_score_df = per_processor()
        """
        ROE_PROCESSOR
        """
        roe_processor = ROE_PROCESSOR(fundamental_df)
        roe_score_df = roe_processor()
        """
        EV_EBITDA_PROCESSOR
        """
        ev_ebitda_processor = EV_EBITDA_PROCESSOR(fundamental_df)
        ev_ebitda_score_df = ev_ebitda_processor()
        score_df = (
            pbr_score_df.merge(per_score_df.loc[:, ["SYMBOL", "PER_SCORE"]], on="SYMBOL")
            .merge(roe_score_df.loc[:, ["SYMBOL", "ROE_SCORE"]], on="SYMBOL")
            .merge(ev_ebitda_score_df.loc[:, ["SYMBOL", "EV_EBITDA_SCORE"]], on="SYMBOL")
        )
        score_df.dropna(inplace=True)
        score_df.iloc[:, 1:] = mms.fit_transform(score_df.iloc[:, 1:])
        
        score_df["SCORE"] = (
            score_df["PBR_SCORE"] * 0
            + score_df["PER_SCORE"] * 1
            + score_df["ROE_SCORE"] * 0
            + score_df["EV_EBITDA_SCORE"] * 0
        )

        score_df["CLOSE"] = score_df["SYMBOL"].map(symbol_close_dict)

        """
        BUYING_ORDER_PROCESSOR
        """
        buying_order_processor = BUYING_ORDER_PROCESSOR(
            score_df, invest_money, status_df, CFG["buying_order_n"]
        )
        buying_orders = buying_order_processor()

        """
        SELLING_ORDER_PROCESSOR
        """
        selling_order_processor = SELLING_ORDER_PROCESSOR(
            score_df, status_df, CFG["selling_order_percentage"]
        )
        selling_orders = selling_order_processor()

        symbols_and_orders = buying_orders + selling_orders
        return symbols_and_orders
    except:
        return []

# %%
def trade_func_roe(
    date: dt.date,
    dict_df_result: dict[str, pd.DataFrame],
    dict_df_position: dict[str, pd.DataFrame],
    logger: logging.Logger,
) -> list[tuple[str, int]]:
    try:
        """
        STATUS_LOADER
        """
        status_loader = STATUS_LOADER(dict_df_result, dict_df_position)

        current_cash = status_loader.get_current_cash()
        invest_money = current_cash * 0.75

        status_df = status_loader.get_status_df()
        position_symbols = sorted(set(status_df["SYMBOL"]))

        """
        SYMBOL_LOADER
        """
        symbol_loader = SYMBOL_LOADER()
        total_symbols = symbol_loader()

        sampled_symbols = random.sample(total_symbols, CFG["sampling_size"])
        using_symbols = sorted(set(sampled_symbols + position_symbols))

        """
        FUNDAMENTAL_LOADER
        """
        fundamental_data_list = list()
        for symbol in using_symbols:
            try:
                _fundamental_loader = FUNDAMENTAL_LOADER(symbol, date)
                _fundamental_data = _fundamental_loader()
                fundamental_data_list.append(_fundamental_data)
            except:
                pass
        fundamental_df = pd.DataFrame(fundamental_data_list)
        symbol_close_dict = fundamental_df.set_index("SYMBOL")["CLOSE"].to_dict()
        
        """
        PBR_PROCESSOR
        """
        pbr_processor = PBR_PROCESSOR(fundamental_df)
        pbr_score_df = pbr_processor()
        """
        PER_PROCESSOR
        """
        per_processor = PER_PROCESSOR(fundamental_df)
        per_score_df = per_processor()
        """
        ROE_PROCESSOR
        """
        roe_processor = ROE_PROCESSOR(fundamental_df)
        roe_score_df = roe_processor()
        """
        EV_EBITDA_PROCESSOR
        """
        ev_ebitda_processor = EV_EBITDA_PROCESSOR(fundamental_df)
        ev_ebitda_score_df = ev_ebitda_processor()
        score_df = (
            pbr_score_df.merge(per_score_df.loc[:, ["SYMBOL", "PER_SCORE"]], on="SYMBOL")
            .merge(roe_score_df.loc[:, ["SYMBOL", "ROE_SCORE"]], on="SYMBOL")
            .merge(ev_ebitda_score_df.loc[:, ["SYMBOL", "EV_EBITDA_SCORE"]], on="SYMBOL")
        )
        score_df.dropna(inplace=True)
        score_df.iloc[:, 1:] = mms.fit_transform(score_df.iloc[:, 1:])
        
        score_df["SCORE"] = (
            score_df["PBR_SCORE"] * 0
            + score_df["PER_SCORE"] * 0
            + score_df["ROE_SCORE"] * 1
            + score_df["EV_EBITDA_SCORE"] * 0
        )

        score_df["CLOSE"] = score_df["SYMBOL"].map(symbol_close_dict)

        """
        BUYING_ORDER_PROCESSOR
        """
        buying_order_processor = BUYING_ORDER_PROCESSOR(
            score_df, invest_money, status_df, CFG["buying_order_n"]
        )
        buying_orders = buying_order_processor()

        """
        SELLING_ORDER_PROCESSOR
        """
        selling_order_processor = SELLING_ORDER_PROCESSOR(
            score_df, status_df, CFG["selling_order_percentage"]
        )
        selling_orders = selling_order_processor()

        symbols_and_orders = buying_orders + selling_orders
        return symbols_and_orders
    except:
        return []

# %%
def trade_func_ev(
    date: dt.date,
    dict_df_result: dict[str, pd.DataFrame],
    dict_df_position: dict[str, pd.DataFrame],
    logger: logging.Logger,
) -> list[tuple[str, int]]:
    try:
        """
        STATUS_LOADER
        """
        status_loader = STATUS_LOADER(dict_df_result, dict_df_position)

        current_cash = status_loader.get_current_cash()
        invest_money = current_cash * 0.75

        status_df = status_loader.get_status_df()
        position_symbols = sorted(set(status_df["SYMBOL"]))

        """
        SYMBOL_LOADER
        """
        symbol_loader = SYMBOL_LOADER()
        total_symbols = symbol_loader()

        sampled_symbols = random.sample(total_symbols, CFG["sampling_size"])
        using_symbols = sorted(set(sampled_symbols + position_symbols))

        """
        FUNDAMENTAL_LOADER
        """
        fundamental_data_list = list()
        for symbol in using_symbols:
            try:
                _fundamental_loader = FUNDAMENTAL_LOADER(symbol, date)
                _fundamental_data = _fundamental_loader()
                fundamental_data_list.append(_fundamental_data)
            except:
                pass
        fundamental_df = pd.DataFrame(fundamental_data_list)
        symbol_close_dict = fundamental_df.set_index("SYMBOL")["CLOSE"].to_dict()
        
        """
        PBR_PROCESSOR
        """
        pbr_processor = PBR_PROCESSOR(fundamental_df)
        pbr_score_df = pbr_processor()
        """
        PER_PROCESSOR
        """
        per_processor = PER_PROCESSOR(fundamental_df)
        per_score_df = per_processor()
        """
        ROE_PROCESSOR
        """
        roe_processor = ROE_PROCESSOR(fundamental_df)
        roe_score_df = roe_processor()
        """
        EV_EBITDA_PROCESSOR
        """
        ev_ebitda_processor = EV_EBITDA_PROCESSOR(fundamental_df)
        ev_ebitda_score_df = ev_ebitda_processor()
        score_df = (
            pbr_score_df.merge(per_score_df.loc[:, ["SYMBOL", "PER_SCORE"]], on="SYMBOL")
            .merge(roe_score_df.loc[:, ["SYMBOL", "ROE_SCORE"]], on="SYMBOL")
            .merge(ev_ebitda_score_df.loc[:, ["SYMBOL", "EV_EBITDA_SCORE"]], on="SYMBOL")
        )
        score_df.dropna(inplace=True)
        score_df.iloc[:, 1:] = mms.fit_transform(score_df.iloc[:, 1:])
        
        score_df["SCORE"] = (
            score_df["PBR_SCORE"] * 0
            + score_df["PER_SCORE"] * 0
            + score_df["ROE_SCORE"] * 0
            + score_df["EV_EBITDA_SCORE"] * 1
        )

        score_df["CLOSE"] = score_df["SYMBOL"].map(symbol_close_dict)

        """
        BUYING_ORDER_PROCESSOR
        """
        buying_order_processor = BUYING_ORDER_PROCESSOR(
            score_df, invest_money, status_df, CFG["buying_order_n"]
        )
        buying_orders = buying_order_processor()

        """
        SELLING_ORDER_PROCESSOR
        """
        selling_order_processor = SELLING_ORDER_PROCESSOR(
            score_df, status_df, CFG["selling_order_percentage"]
        )
        selling_orders = selling_order_processor()

        symbols_and_orders = buying_orders + selling_orders
        return symbols_and_orders
    except:
        return []

# %%
# # loop
# dict_df_result = kq.backtest_stock_port_daily(
#     trade_func,
#     "2023-08-01",  # 실제 심사에서는 투자기간 시작일
#     "2023-08-31",  # 실제 심사에서는 투자기간 종료일
#     init_cash=1_000_000_000,  # 10억원
# )

# %%
import kquant as kq
import datetime as dt

dict_df_result_1, dict_df_position_1, logger = kq.backtest_stock_port_daily(
    trade_func_pbr,
    "2023-08-01",
    "2023-08-01",
    init_cash=1_000_000_000,
    return_position=True,
    return_logger=True,
)

date = dt.date(2023, 8, 2)
symbols_and_orders = trade_func_pbr(
    date,
    dict_df_result_1,
    dict_df_position_1,
    logger,
)
dict_df_result_2, dict_df_position_2 = kq.backtest_update_stock_port_daily(
    symbols_and_orders,
    date,
    dict_df_result_1,
    dict_df_position_1,
)
date = dt.date(2023, 8, 3)

symbols_and_orders = trade_func_pbr(
    date,
    dict_df_result_2,
    dict_df_position_2,
    logger,
)

dict_df_result_3, dict_df_position_3 = kq.backtest_update_stock_port_daily(
    symbols_and_orders,
    date,
    dict_df_result_2,
    dict_df_position_2,
)

date = dt.date(2023, 8, 31)

dict_df_result_4, dict_df_position_4 = kq.backtest_update_stock_port_daily(
    [],
    date,
    dict_df_result_3,
    dict_df_position_3,
)
per_result = dict_df_result_4["TOTAL"]["TOTAL_VALUE"].tail(1).values[0]
# Out:
# 100%|██████████| 200/200 [02:44<00:00,  1.22it/s]
# [2023-08-01] 종목: 004960, 주문전 보유수량:      0 주문수량: 21,024, 매매수량: 21,024, 주문후 보유수량: 21,024
# [2023-08-01] 종목: 058650, 주문전 보유수량:      0 주문수량:  1,203, 매매수량:  1,203, 주문후 보유수량:  1,203
# [2023-08-01] 종목: 006360, 주문전 보유수량:      0 주문수량:  5,856, 매매수량:  5,856, 주문후 보유수량:  5,856
# [2023-08-01] 종목: 004360, 주문전 보유수량:      0 주문수량:  6,888, 매매수량:  6,888, 주문후 보유수량:  6,888
# [2023-08-01] 종목: 005960, 주문전 보유수량:      0 주문수량: 12,649, 매매수량: 12,649, 주문후 보유수량: 12,649
# [2023-08-01] 종목: 088350, 주문전 보유수량:      0 주문수량: 31,634, 매매수량: 31,634, 주문후 보유수량: 31,634
# [2023-08-01] 종목: 000240, 주문전 보유수량:      0 주문수량:  5,763, 매매수량:  5,763, 주문후 보유수량:  5,763
# [2023-08-01] 종목: 002240, 주문전 보유수량:      0 주문수량:  2,848, 매매수량:  2,848, 주문후 보유수량:  2,848
# 100%|██████████| 208/208 [02:38<00:00,  1.31it/s]
# [2023-08-02] 종목: 005440, 주문전 보유수량:      0 주문수량: 13,769, 매매수량: 13,769, 주문후 보유수량: 13,769
# [2023-08-02] 종목: 000880, 주문전 보유수량:      0 주문수량:  1,329, 매매수량:  1,329, 주문후 보유수량:  1,329
# [2023-08-02] 종목: 007860, 주문전 보유수량:      0 주문수량:  2,518, 매매수량:  2,518, 주문후 보유수량:  2,518
# [2023-08-02] 종목: 267250, 주문전 보유수량:      0 주문수량:    323, 매매수량:    323, 주문후 보유수량:    323
# [2023-08-02] 종목: 057050, 주문전 보유수량:      0 주문수량:    376, 매매수량:    376, 주문후 보유수량:    376
# [2023-08-02] 종목: 316140, 주문전 보유수량:      0 주문수량:  1,336, 매매수량:  1,336, 주문후 보유수량:  1,336
# [2023-08-02] 종목: 121440, 주문전 보유수량:      0 주문수량:  3,504, 매매수량:  3,504, 주문후 보유수량:  3,504
# [2023-08-02] 종목: 003480, 주문전 보유수량:      0 주문수량:  4,431, 매매수량:  4,431, 주문후 보유수량:  4,431
# 100%|██████████| 212/212 [03:05<00:00,  1.14it/s]
# [2023-08-03] 종목: 005740, 주문전 보유수량:      0 주문수량:  1,459, 매매수량:  1,459, 주문후 보유수량:  1,459
# [2023-08-03] 종목: 035810, 주문전 보유수량:      0 주문수량:  2,601, 매매수량:  2,601, 주문후 보유수량:  2,601
# [2023-08-03] 종목: 004150, 주문전 보유수량:      0 주문수량:  2,331, 매매수량:  2,331, 주문후 보유수량:  2,331
# [2023-08-03] 종목: 001800, 주문전 보유수량:      0 주문수량:    430, 매매수량:    430, 주문후 보유수량:    430
# [2023-08-03] 종목: 000070, 주문전 보유수량:      0 주문수량:     79, 매매수량:     79, 주문후 보유수량:     79
# [2023-08-03] 종목: 024720, 주문전 보유수량:      0 주문수량:    328, 매매수량:    328, 주문후 보유수량:    328
# [2023-08-03] 종목: 021320, 주문전 보유수량:      0 주문수량:    815, 매매수량:    815, 주문후 보유수량:    815
# [2023-08-03] 종목: 009580, 주문전 보유수량:      0 주문수량:  1,214, 매매수량:  1,214, 주문후 보유수량:  1,214

# %%
pbr_result = dict_df_result_4["TOTAL"]["TOTAL_VALUE"].tail(1).values[0]
# Out:
# 992653345

# %%
import kquant as kq
import datetime as dt

dict_df_result_1, dict_df_position_1, logger = kq.backtest_stock_port_daily(
    trade_func_per,
    "2023-08-01",
    "2023-08-01",
    init_cash=1_000_000_000,
    return_position=True,
    return_logger=True,
)

date = dt.date(2023, 8, 2)
symbols_and_orders = trade_func_per(
    date,
    dict_df_result_1,
    dict_df_position_1,
    logger,
)
dict_df_result_2, dict_df_position_2 = kq.backtest_update_stock_port_daily(
    symbols_and_orders,
    date,
    dict_df_result_1,
    dict_df_position_1,
)
date = dt.date(2023, 8, 3)

symbols_and_orders = trade_func_per(
    date,
    dict_df_result_2,
    dict_df_position_2,
    logger,
)

dict_df_result_3, dict_df_position_3 = kq.backtest_update_stock_port_daily(
    symbols_and_orders,
    date,
    dict_df_result_2,
    dict_df_position_2,
)

date = dt.date(2023, 8, 31)

dict_df_result_4, dict_df_position_4 = kq.backtest_update_stock_port_daily(
    [],
    date,
    dict_df_result_3,
    dict_df_position_3,
)
per_result = dict_df_result_4["TOTAL"]["TOTAL_VALUE"].tail(1).values[0]
# Out:
# [2023-08-01] 종목: 375500, 주문전 보유수량:      0 주문수량:  3,909, 매매수량:  3,909, 주문후 보유수량:  3,909
# [2023-08-01] 종목: 069920, 주문전 보유수량:      0 주문수량: 38,730, 매매수량: 38,730, 주문후 보유수량: 38,730
# [2023-08-01] 종목: 009200, 주문전 보유수량:      0 주문수량: 45,938, 매매수량: 45,938, 주문후 보유수량: 45,938
# [2023-08-01] 종목: 003960, 주문전 보유수량:      0 주문수량:  3,975, 매매수량:  3,975, 주문후 보유수량:  3,975
# [2023-08-01] 종목: 010950, 주문전 보유수량:      0 주문수량:  1,077, 매매수량:  1,077, 주문후 보유수량:  1,077
# [2023-08-01] 종목: 009070, 주문전 보유수량:      0 주문수량: 18,836, 매매수량: 18,836, 주문후 보유수량: 18,836
# [2023-08-01] 종목: 001450, 주문전 보유수량:      0 주문수량:  2,559, 매매수량:  2,559, 주문후 보유수량:  2,559
# [2023-08-01] 종목: 253840, 주문전 보유수량:      0 주문수량:  8,907, 매매수량:  8,907, 주문후 보유수량:  8,907
# [2023-08-02] 종목: 244920, 주문전 보유수량:      0 주문수량: 12,707, 매매수량: 12,707, 주문후 보유수량: 12,707
# [2023-08-02] 종목: 093050, 주문전 보유수량:      0 주문수량:  2,345, 매매수량:  2,345, 주문후 보유수량:  2,345
# [2023-08-02] 종목: 009180, 주문전 보유수량:      0 주문수량: 10,648, 매매수량: 10,648, 주문후 보유수량: 10,648
# [2023-08-02] 종목: 306040, 주문전 보유수량:      0 주문수량:  1,993, 매매수량:  1,993, 주문후 보유수량:  1,993
# [2023-08-02] 종목: 115570, 주문전 보유수량:      0 주문수량:  4,168, 매매수량:  4,168, 주문후 보유수량:  4,168
# [2023-08-02] 종목: 040300, 주문전 보유수량:      0 주문수량:  1,756, 매매수량:  1,756, 주문후 보유수량:  1,756
# [2023-08-02] 종목: 054220, 주문전 보유수량:      0 주문수량: 22,460, 매매수량: 22,460, 주문후 보유수량: 22,460
# [2023-08-02] 종목: 130580, 주문전 보유수량:      0 주문수량:  1,872, 매매수량:  1,872, 주문후 보유수량:  1,872
# [2023-08-03] 종목: 004720, 주문전 보유수량:      0 주문수량:  2,141, 매매수량:  2,141, 주문후 보유수량:  2,141
# [2023-08-03] 종목: 227840, 주문전 보유수량:      0 주문수량:    558, 매매수량:    558, 주문후 보유수량:    558
# [2023-08-03] 종목: 084690, 주문전 보유수량:      0 주문수량:    912, 매매수량:    912, 주문후 보유수량:    912
# [2023-08-03] 종목: 213500, 주문전 보유수량:      0 주문수량:    513, 매매수량:    513, 주문후 보유수량:    513
# [2023-08-03] 종목: 079940, 주문전 보유수량:      0 주문수량:    404, 매매수량:    404, 주문후 보유수량:    404
# [2023-08-03] 종목: 100790, 주문전 보유수량:      0 주문수량:    745, 매매수량:    745, 주문후 보유수량:    745
# [2023-08-03] 종목: 015230, 주문전 보유수량:      0 주문수량:    490, 매매수량:    490, 주문후 보유수량:    490
# [2023-08-03] 종목: 086280, 주문전 보유수량:      0 주문수량:     20, 매매수량:     20, 주문후 보유수량:     20

# %%
import kquant as kq
import datetime as dt

dict_df_result_1, dict_df_position_1, logger = kq.backtest_stock_port_daily(
    trade_func_roe,
    "2023-08-01",
    "2023-08-01",
    init_cash=1_000_000_000,
    return_position=True,
    return_logger=True,
)

date = dt.date(2023, 8, 2)
symbols_and_orders = trade_func_roe(
    date,
    dict_df_result_1,
    dict_df_position_1,
    logger,
)
dict_df_result_2, dict_df_position_2 = kq.backtest_update_stock_port_daily(
    symbols_and_orders,
    date,
    dict_df_result_1,
    dict_df_position_1,
)
date = dt.date(2023, 8, 3)

symbols_and_orders = trade_func_roe(
    date,
    dict_df_result_2,
    dict_df_position_2,
    logger,
)

dict_df_result_3, dict_df_position_3 = kq.backtest_update_stock_port_daily(
    symbols_and_orders,
    date,
    dict_df_result_2,
    dict_df_position_2,
)

date = dt.date(2023, 8, 31)

dict_df_result_4, dict_df_position_4 = kq.backtest_update_stock_port_daily(
    [],
    date,
    dict_df_result_3,
    dict_df_position_3,
)
roe_result = dict_df_result_4["TOTAL"]["TOTAL_VALUE"].tail(1).values[0]
# Out:
# [2023-08-01] 종목: 106240, 주문전 보유수량:      0 주문수량: 211,940, 매매수량: 211,940, 주문후 보유수량: 211,940
# [2023-08-01] 종목: 335890, 주문전 보유수량:      0 주문수량:  9,991, 매매수량:  9,991, 주문후 보유수량:  9,991
# [2023-08-01] 종목: 071280, 주문전 보유수량:      0 주문수량:  7,091, 매매수량:  7,091, 주문후 보유수량:  7,091
# [2023-08-01] 종목: 053610, 주문전 보유수량:      0 주문수량:    687, 매매수량:    687, 주문후 보유수량:    687
# [2023-08-01] 종목: 194370, 주문전 보유수량:      0 주문수량:  2,650, 매매수량:  2,650, 주문후 보유수량:  2,650
# [2023-08-01] 종목: 263860, 주문전 보유수량:      0 주문수량:  2,659, 매매수량:  2,659, 주문후 보유수량:  2,659
# [2023-08-01] 종목: 264660, 주문전 보유수량:      0 주문수량:  2,326, 매매수량:  2,326, 주문후 보유수량:  2,326
# [2023-08-01] 종목: 069330, 주문전 보유수량:      0 주문수량: 19,927, 매매수량: 19,927, 주문후 보유수량: 19,927
# [2023-08-02] 종목: 205470, 주문전 보유수량:      0 주문수량: 16,920, 매매수량: 16,920, 주문후 보유수량: 16,920
# [2023-08-02] 종목: 039560, 주문전 보유수량:      0 주문수량:  6,917, 매매수량:  6,917, 주문후 보유수량:  6,917
# [2023-08-02] 종목: 092130, 주문전 보유수량:      0 주문수량:  2,051, 매매수량:  2,051, 주문후 보유수량:  2,051
# [2023-08-02] 종목: 290670, 주문전 보유수량:      0 주문수량:    473, 매매수량:    473, 주문후 보유수량:    473
# [2023-08-02] 종목: 089970, 주문전 보유수량:      0 주문수량:  1,122, 매매수량:  1,122, 주문후 보유수량:  1,122
# [2023-08-02] 종목: 230360, 주문전 보유수량:      0 주문수량:  1,492, 매매수량:  1,492, 주문후 보유수량:  1,492
# [2023-08-02] 종목: 036710, 주문전 보유수량:      0 주문수량:  4,635, 매매수량:  4,635, 주문후 보유수량:  4,635
# [2023-08-02] 종목: 131290, 주문전 보유수량:      0 주문수량:    267, 매매수량:    267, 주문후 보유수량:    267
# [2023-08-03] 종목: 348210, 주문전 보유수량:      0 주문수량:    141, 매매수량:    141, 주문후 보유수량:    141
# [2023-08-03] 종목: 024850, 주문전 보유수량:      0 주문수량:  3,490, 매매수량:  3,490, 주문후 보유수량:  3,490
# [2023-08-03] 종목: 099430, 주문전 보유수량:      0 주문수량:    602, 매매수량:    602, 주문후 보유수량:    602
# [2023-08-03] 종목: 015230, 주문전 보유수량:      0 주문수량:    531, 매매수량:    531, 주문후 보유수량:    531
# [2023-08-03] 종목: 377450, 주문전 보유수량:      0 주문수량:    483, 매매수량:    483, 주문후 보유수량:    483
# [2023-08-03] 종목: 065710, 주문전 보유수량:      0 주문수량:    201, 매매수량:    201, 주문후 보유수량:    201
# [2023-08-03] 종목: 030190, 주문전 보유수량:      0 주문수량:    356, 매매수량:    356, 주문후 보유수량:    356
# [2023-08-03] 종목: 054040, 주문전 보유수량:      0 주문수량:    873, 매매수량:    873, 주문후 보유수량:    873

# %%
import kquant as kq
import datetime as dt

dict_df_result_1, dict_df_position_1, logger = kq.backtest_stock_port_daily(
    trade_func_ev,
    "2023-08-01",
    "2023-08-01",
    init_cash=1_000_000_000,
    return_position=True,
    return_logger=True,
)

date = dt.date(2023, 8, 2)
symbols_and_orders = trade_func_ev(
    date,
    dict_df_result_1,
    dict_df_position_1,
    logger,
)
dict_df_result_2, dict_df_position_2 = kq.backtest_update_stock_port_daily(
    symbols_and_orders,
    date,
    dict_df_result_1,
    dict_df_position_1,
)
date = dt.date(2023, 8, 3)

symbols_and_orders = trade_func_ev(
    date,
    dict_df_result_2,
    dict_df_position_2,
    logger,
)

dict_df_result_3, dict_df_position_3 = kq.backtest_update_stock_port_daily(
    symbols_and_orders,
    date,
    dict_df_result_2,
    dict_df_position_2,
)

date = dt.date(2023, 8, 31)

dict_df_result_4, dict_df_position_4 = kq.backtest_update_stock_port_daily(
    [],
    date,
    dict_df_result_3,
    dict_df_position_3,
)
ev_result = dict_df_result_4["TOTAL"]["TOTAL_VALUE"].tail(1).values[0]
# Out:
# [2023-08-01] 종목: 029460, 주문전 보유수량:      0 주문수량: 27,612, 매매수량: 27,612, 주문후 보유수량: 27,612
# [2023-08-01] 종목: 005960, 주문전 보유수량:      0 주문수량: 14,972, 매매수량: 14,972, 주문후 보유수량: 14,972
# [2023-08-01] 종목: 010060, 주문전 보유수량:      0 주문수량:    509, 매매수량:    509, 주문후 보유수량:    509
# [2023-08-01] 종목: 001230, 주문전 보유수량:      0 주문수량:  1,899, 매매수량:  1,899, 주문후 보유수량:  1,899
# [2023-08-01] 종목: 297890, 주문전 보유수량:      0 주문수량:  3,814, 매매수량:  3,814, 주문후 보유수량:  3,814
# [2023-08-01] 종목: 036800, 주문전 보유수량:      0 주문수량:    708, 매매수량:    708, 주문후 보유수량:    708
# [2023-08-01] 종목: 012630, 주문전 보유수량:      0 주문수량:  2,179, 매매수량:  2,179, 주문후 보유수량:  2,179
# [2023-08-01] 종목: 080010, 주문전 보유수량:      0 주문수량:  1,926, 매매수량:  1,926, 주문후 보유수량:  1,926
# [2023-08-02] 종목: 065680, 주문전 보유수량:      0 주문수량:  3,281, 매매수량:  3,281, 주문후 보유수량:  3,281
# [2023-08-02] 종목: 104480, 주문전 보유수량:      0 주문수량: 13,022, 매매수량: 13,022, 주문후 보유수량: 13,022
# [2023-08-02] 종목: 187870, 주문전 보유수량:      0 주문수량:  1,522, 매매수량:  1,522, 주문후 보유수량:  1,522
# [2023-08-02] 종목: 021650, 주문전 보유수량:      0 주문수량:  7,182, 매매수량:  7,182, 주문후 보유수량:  7,182
# [2023-08-02] 종목: 004360, 주문전 보유수량:      0 주문수량:  1,576, 매매수량:  1,576, 주문후 보유수량:  1,576
# [2023-08-02] 종목: 080220, 주문전 보유수량:      0 주문수량:  4,201, 매매수량:  4,201, 주문후 보유수량:  4,201
# [2023-08-02] 종목: 163560, 주문전 보유수량:      0 주문수량:  2,462, 매매수량:  2,462, 주문후 보유수량:  2,462
# [2023-08-02] 종목: 064960, 주문전 보유수량:      0 주문수량:    274, 매매수량:    274, 주문후 보유수량:    274
# [2023-08-03] 종목: 001130, 주문전 보유수량:      0 주문수량:    326, 매매수량:    326, 주문후 보유수량:    326
# [2023-08-03] 종목: 057050, 주문전 보유수량:      0 주문수량:     31, 매매수량:     31, 주문후 보유수량:     31
# [2023-08-03] 종목: 026040, 주문전 보유수량:      0 주문수량:    523, 매매수량:    523, 주문후 보유수량:    523
# [2023-08-03] 종목: 049070, 주문전 보유수량:      0 주문수량:     21, 매매수량:     21, 주문후 보유수량:     21
# [2023-08-03] 종목: 001120, 주문전 보유수량:      0 주문수량:     17, 매매수량:     17, 주문후 보유수량:     17
# [2023-08-03] 종목: 058850, 주문전 보유수량:      0 주문수량:    131, 매매수량:    131, 주문후 보유수량:    131
# [2023-08-03] 종목: 000990, 주문전 보유수량:      0 주문수량:      5, 매매수량:      5, 주문후 보유수량:      5
# [2023-08-03] 종목: 030530, 주문전 보유수량:      0 주문수량:     89, 매매수량:     89, 주문후 보유수량:     89

# %%
pbr_result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/jack/Desktop/things/project/krx/krx_final/krx_production/model_comparison.ipynb Cell 23 line 1
# ----> <a href='vscode-notebook-cell:/Users/jack/Desktop/things/project/krx/krx_final/krx_production/model_comparison.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> pbr_result
#
# NameError: name 'pbr_result' is not defined

# %%
per_result
# Out:
# 1024614605

# %%
roe_result
# Out:
# 971358456

# %%
ev_result
# Out:
# 960055035

# %%
from typing import Any


class A_PREPROCESSOR:
    def __init__(self, value) -> None:
        self.value = value

    def __call__(self) -> Any:
        value = self.value
        value = value + 1
        return value


class A_PROCESSOR:
    def __init__(self, value, alpha) -> None:
        self.value = value
        self.alpha = alpha

    def __call__(self) -> Any:
        value = self.value
        alpha = self.alpha
        value = value**alpha
        return value


class A_POSTPROCESSOR:
    def __init__(self, value, beta) -> None:
        self.value = value
        self.beta = beta

    def __call__(self) -> Any:
        value = self.value
        beta = self.beta
        value = value + beta
        return value

# %%
value = 1
alpha = 2
beta = 3

a_preprocessor = A_PREPROCESSOR(value)
preprocessed_a = a_preprocessor()

a_processor = A_PROCESSOR(preprocessed_a, alpha)
processed_a = a_processor()

a_postprocessor = A_POSTPROCESSOR(processed_a, beta)
postprocessed_a = a_postprocessor()
postprocessed_a
# Out:
# 7

# %%
value = 1
alpha = 2
beta = 3

a_preprocessor = A_PREPROCESSOR(value)
preprocessed_a = a_preprocessor()

a_processor = A_PROCESSOR(preprocessed_a, alpha)
processed_a = a_processor()

a_postprocessor = A_POSTPROCESSOR(processed_a, beta)
postprocessed_a = a_postprocessor()
postprocessed_a

class A:
    def __init__(self, A_PREPROCESSOR, A_PROCESSOR, A_POSTPROCESSOR) -> None:
        self.A_PREPROCESSOR = A_PREPROCESSOR
        self.A_PROCESSOR = A_PROCESSOR
        self.A_POSTPROCESSOR = A_POSTPROCESSOR

    def __call__(self) -> Any:
        val = self.A_POSTPROCESSOR()

# %%
class A:
    def __init__(self, A_PREPROCESSOR, A_PROCESSOR, A_POSTPROCESSOR) -> None:
        self.A_PREPROCESSOR = A_PREPROCESSOR
        self.A_PROCESSOR = A_PROCESSOR
        self.A_POSTPROCESSOR = A_POSTPROCESSOR

    def __call__(self) -> Any:
        val = self.A_POSTPROCESSOR()

# %%
from typing import Any


class A_PREPROCESSOR:
    def __init__(self, value) -> None:
        self.value = value

    def __call__(self) -> Any:
        value = self.value
        value = value + 1
        return value


class A_PROCESSOR:
    def __init__(self, alpha) -> None:
        self.alpha = alpha

    def __call__(self, value) -> Any:
        alpha = self.alpha
        value = value**alpha
        return value


class A_POSTPROCESSOR:
    def __init__(self, beta) -> None:
        self.beta = beta

    def __call__(self, value) -> Any:
        beta = self.beta
        value = value + beta
        return value


class A:
    def __init__(self, A_PREPROCESSOR, A_PROCESSOR, A_POSTPROCESSOR) -> None:
        self.A_PREPROCESSOR = A_PREPROCESSOR
        self.A_PROCESSOR = A_PROCESSOR
        self.A_POSTPROCESSOR = A_POSTPROCESSOR

    def __call__(self) -> Any:
        # 전처리 수행
        preprocessed_value = self.A_PREPROCESSOR()

        # 처리 수행
        processed_value = self.A_PROCESSOR(preprocessed_value)

        # 후처리 수행
        postprocessed_value = self.A_POSTPROCESSOR(processed_value)

        return postprocessed_value


# 각각의 클래스에 대한 인스턴스를 생성합니다.
value = 1
alpha = 2
beta = 3

a_preprocessor = A_PREPROCESSOR(value)
a_processor = A_PROCESSOR(alpha)
a_postprocessor = A_POSTPROCESSOR(beta)

# 클래스 A의 인스턴스를 생성하고 파이프라인을 실행합니다.
a_pipeline = A(a_preprocessor, a_processor, a_postprocessor)
result = a_pipeline()

# 최종 결과를 출력합니다.
print(result)
# Out:
# 7
