# %%
from tqdm import tqdm

# %%
CFG = {
    "buying_order_n": 8,
    "selling_order_percentage": 40,
    "sampling_size": 250,
}

# %%
import datetime as dt
import random

import numpy as np
import pandas as pd

import kquant as kq


# API_account
def set_api_account():
    kq.set_api("KRX2308020", "EQDkUcyI3dK6oIAXqAR8BXOK4bKxHHmH")
    return None


set_api_account()

# %%
class STATUS_LOADER:
    """
    STATUS_LOADER : 상태 정보 추출 클래스
    """

    def __init__(self, dict_df_result: dict, dict_df_position: dict) -> None:
        """
        STATUS_LOADER의 생성자

        :param dict dict_df_result: dict_df_result 입니다.
        :param dict dict_df_position: dict_df_position 입니다.
        :return: None
        :rtype: None
        """
        self.dict_df_result = dict_df_result
        self.dict_df_position = dict_df_position

    def get_current_cash(self) -> float:
        """
        현재 보유 cash를 반환하는 메서드

        :return : 현재 보유 cash
        :rtype: float
        """
        _dict_df_result = self.dict_df_result
        try:
            _df_result_total = _dict_df_result["TOTAL"]
            _current_cash = (
                _df_result_total.sort_values("DATE").tail(1)["CASH"].values[0]
            )
            return _current_cash
        except:
            return 1_000_000_000.0

    def get_status_df(self) -> pd.DataFrame:
        """
        현재 보유 position 관련 정보를 반환하는 메서드

        :return: 보유한 symbol, 갯수, 구매가격, 현재 가격을 데이터프레임 형태로 가져옵니다.
        :rtype: pd.DataFrame
        """
        current_symbol_list = list()
        _dict_df_result = self.dict_df_result
        _dict_df_position = self.dict_df_position

        _total_symbols = sorted(_dict_df_position.keys())

        for _symbol in _total_symbols:
            try:
                _symbol_result_df = _dict_df_result[_symbol]
                _symbol_position_df = _dict_df_position[_symbol]

                _current_price = (
                    _symbol_result_df.sort_values("DATE").tail(1)["PRICE"].values[0]
                )
                _trade_price = _symbol_position_df["TRADE_PRICE"].values[0]
                _current_qty = _symbol_position_df["QTY"].values[0]

                current_symbol_list.append(
                    {
                        "SYMBOL": _symbol,
                        "CURRENT_QTY": _current_qty,
                        "CURRENT_PRICE": _current_price,
                        "TRADE_PRICE": _trade_price,
                    }
                )
            except:
                pass
        return pd.DataFrame(
            current_symbol_list,
            columns=["SYMBOL", "CURRENT_QTY", "CURRENT_PRICE", "TRADE_PRICE"],
        )

# %%
class SYMBOL_LOADER:
    """
    SYMBOL_LOADER : 거래가능한 주식 symbol을 필터-추출하는 클래스
    """

    @staticmethod
    def load_symbols_df() -> pd.DataFrame:
        """
        한국거래소 종목 목록 데이터프레임을 호출하는 메서드

        :return : 한국거래소 종목 목록 데이터프레임
        :rtype : pd.DataFrame
        """
        symbols_df = kq.symbol_stock()
        return symbols_df

    class SYMBOL_FILTER:
        """
        SYMBOl_FILTER : symbols를 filtering 하는 클래스
        """

        @staticmethod
        def filter__market(symbols_df: pd.DataFrame) -> pd.DataFrame:
            """
            market에 대한 필터링을 진행하는 메서드

            :param pd.DataFrame : symbols_df : 한국거래소 종목 목록 데이터프레임
            :return: MARKET이 [코스닥, 유가증권]에 속하는 데이터프레임
            :rtype: pd.DataFrame
            """
            filtered_symbols_df = symbols_df[
                (symbols_df["MARKET"].isin(["코스닥", "유가증권"]))
            ].copy()
            return filtered_symbols_df

        @staticmethod
        def filter__admin_issue(symbols_df: pd.DataFrame) -> pd.DataFrame:
            """
            ADMIN_ISSUE에 대한 필터링을 진행하는 메서드

            :param pd.DataFrame : symbols_df : 한국거래소 종목 목록 데이터프레임
            :return: ADMIN_ISSUE가 0인 데이터프레임
            :rtype: pd.DataFrame
            """
            filtered_symbols_df = symbols_df[(symbols_df["ADMIN_ISSUE"] == 0)].copy()
            return filtered_symbols_df

        @staticmethod
        def filter_sec_type(symbols_df: pd.DataFrame) -> pd.DataFrame:
            """
            SEC_TYPE에 대한 필터링을 진행하는 메서드

            :param pd.DataFrame : symbols_df : 한국거래소 종목 목록 데이터프레임
            :return: SEC_TYPE이 [ST, EF, EN]에 속하는 데이터프레임
            :rtype: pd.DataFrame
            """
            filtered_symbols_df = symbols_df[
                symbols_df["SEC_TYPE"].isin(["ST", "EF", "EN"])
            ].copy()
            return filtered_symbols_df

    def filter_symbols_df(self, symbols_df: pd.DataFrame) -> pd.DataFrame:
        """
        symbol_df 에 대한 필터링을 진행하는 메서드

        :param pd.DataFrame : symbols_df : 한국거래소 종목 목록 데이터프레임
        :return: SYMBOL_FILTER의 메서드를 거친 데이터프레임
        :rtype: pd.DataFrame
        """
        symbol_filter = self.SYMBOL_FILTER()
        filtered_symbols_df = symbol_filter.filter__market(symbols_df)
        filtered_symbols_df = symbol_filter.filter__admin_issue(filtered_symbols_df)
        filtered_symbols_df = symbol_filter.filter_sec_type(filtered_symbols_df)
        return filtered_symbols_df

    @staticmethod
    def get_symbols(symbols_df: pd.DataFrame) -> list:
        """
        symbols_df의 symbol을 중복을 제거하여 추출하는 메서드

        :param pd.DataFrame : symbols_df : 한국거래소 종목 목록 데이터프레임
        :return: symbols
        :rtype: list
        """
        symbols = sorted(set(symbols_df["SYMBOL"]))
        return symbols

    # SYMBOL_LOADER PIPELINE
    def __call__(self) -> list:
        """
        SYMBOL_LOADER의 파이프라인을 제공하는 메서드

        :return: 필터를 거친 symbols
        :rtype: list
        """
        symbols_df = self.load_symbols_df()
        filtered_symbols_df = self.filter_symbols_df(symbols_df)
        symbols = self.get_symbols(filtered_symbols_df)
        return symbols

# %%
class FUNDAMENTAL_LOADER:
    """
    FUNDAMENTAL_LOADER : fundamental_analysis를 위한 정보를 추출하는 클래스
    """

    def __init__(self, symbol: str, date: dt.date) -> None:
        """
        FUNDAMENTAL_LOADER의 생성자

        :param str symbol: stock의 symbol 입니다.
        :param datetime.date date: 현재 날짜 입니다.

        :attr : pd.DataFrmae daily_stock_df : 현재 날짜 기준 가장 최근 stock데이터 입니다.
        """
        self.symbol = symbol
        self.date = date
        self.daily_stock_df = kq.daily_stock(
            symbol,
            start_date=date - dt.timedelta(days=7),
            end_date=date,
        )

    def load_recent_close(self) -> float:
        """
        가장 최근 종가를 추출합니다.
        :return: 종가
        :rtype: float
        """
        daily_stock_df = self.daily_stock_df
        _close = daily_stock_df.sort_values("DATE").tail(1)["CLOSE"].values[0]
        return _close

    def load_recent_marketcap(self) -> float:
        """
        가장 최근 시가총액을 추출합니다.

        :return: 시가총액
        :rtype: float
        """
        daily_stock_df = self.daily_stock_df
        _marketcap = daily_stock_df.sort_values("DATE").tail(1)["MARKETCAP"].values[0]
        return float(_marketcap)

    def load_recent_netprofit(self) -> float:
        """
        공시자료 중 가장 최근 당기순이익을 추출합니다.

        :return: 당기순이익
        :rtype: float
        """
        netprofit_df = kq.account_history(self.symbol, "122700")
        netprofit_df.sort_values("YEARMONTH", inplace=True)
        _netprofit = netprofit_df.tail(1)["VALUE"].values[0] * 1000
        return float(_netprofit)

    def load_recent_assets(self) -> float:
        """
        공시자료 중 가장 최근 총 자산를 추출합니다.

        :return: 총 자산
        :rtype: float
        """
        assets_df = kq.account_history(self.symbol, "111000")
        assets_df.sort_values("YEARMONTH", inplace=True)
        _assets = assets_df.tail(1)["VALUE"].values[0] * 1000
        return float(_assets)

    def load_recent_current_assets(self) -> float:
        """
        공시자료 중 가장 최근 유동 자산를 추출합니다.

        :return: 유동 자산
        :rtype: float
        """
        current_assets_df = kq.account_history(self.symbol, "111100")
        current_assets_df.sort_values("YEARMONTH", inplace=True)
        _current_assets = current_assets_df.tail(1)["VALUE"].values[0] * 1000
        return float(_current_assets)

    def load_recent_liabilities(self) -> float:
        """
        공시자료 중 가장 최근 총 부채를 추출합니다.

        :return: 총 부채
        :rtype: float
        """
        liabilities_df = kq.account_history(self.symbol, "113000")
        liabilities_df.sort_values("YEARMONTH", inplace=True)
        _liabilities = liabilities_df.tail(1)["VALUE"].values[0] * 1000
        return float(_liabilities)

    def load_recent_equity(self) -> float:
        """
        공시자료 중 가장 최근 총 자본(총 자산 - 총 부채)를 추출합니다.

        :return: 총 자본(총 자산 - 총 부채)
        :rtype: float
        """
        equity_df = kq.account_history(self.symbol, "115000")
        equity_df.sort_values("YEARMONTH", inplace=True)
        _equity = equity_df.tail(1)["VALUE"].values[0] * 1000
        return float(_equity)

    def load_recent_EBITDA(self) -> float:
        """
        공시자료 중 가장 최근 EBITDA를 추출합니다.

        :return: EBITDA
        :rtype: float
        """
        ebitda_df = kq.account_history(self.symbol, "123000")
        ebitda_df.sort_values("YEARMONTH", inplace=True)
        _ebitda = ebitda_df.tail(1)["VALUE"].values[0] * 1000
        return float(_ebitda)

    def __call__(self) -> dict:
        """
        fundmanetal analysis를 위해 필요한 데이터를 가져와서 dictionary를 반환한다.

        :return: fundamental analysis를 위한 데이터 dictionary
        :rtype: dict
        """
        _close = self.load_recent_close()
        _marketcap = self.load_recent_marketcap()
        _netprofit = self.load_recent_netprofit()
        _assets = self.load_recent_assets()
        _current_assets = self.load_recent_current_assets()
        _liabilities = self.load_recent_liabilities()
        _equity = self.load_recent_equity()
        _ebitda = self.load_recent_EBITDA()
        return {
            "SYMBOL": self.symbol,
            "CLOSE": _close,
            "MARKETCAP": _marketcap,
            "NETPROFIT": _netprofit,
            "ASSETS": _assets,
            "CURRENT_ASSETS": _current_assets,
            "LIABILITIES": _liabilities,
            "EQUITY": _equity,
            "EBITDA": _ebitda,
        }

# %%
class PBR_PROCESSOR:
    """
    PBR_PROCESSOR : PBR에 대한 정보를 SCORE로 정제하여 반환하는 클래스
    """
    def __init__(self, fundamental_df) -> None:
        self.fundamental_df = fundamental_df

    @staticmethod
    def append_pbr(fundamental_df):
        fundamental_df["PBR"] = fundamental_df["MARKETCAP"] / (
            fundamental_df["EQUITY"]
        )
        return fundamental_df

    @staticmethod
    def filter_negative_pbr(fundamental_df):
        fundamental_df = fundamental_df[fundamental_df["PBR"] > 0]
        return fundamental_df

    @staticmethod
    def append_score(fundamental_df: pd.DataFrame) -> pd.DataFrame:
        fundamental_df["PBR_SCORE"] = fundamental_df["PBR"].sum() / fundamental_df["PBR"]
        return fundamental_df

    def __call__(self):
        fundamental_df = self.fundamental_df

        fundamental_df = self.append_pbr(fundamental_df)
        fundamental_df = self.filter_negative_pbr(fundamental_df)
        fundamental_df = self.append_score(fundamental_df)

        score_df = fundamental_df.loc[:, ["SYMBOL", "PBR_SCORE"]]
        return score_df

# %%
class PER_PROCESSOR:
    """
    PBR_PROCESSOR : PBR에 대한 정보를 SCORE로 정제하여 반환하는 클래스
    """
    def __init__(self, fundamental_df) -> None:
        self.fundamental_df = fundamental_df

    @staticmethod
    def append_per(fundamental_df):
        fundamental_df["PER"] = fundamental_df["MARKETCAP"] / (
            fundamental_df["NETPROFIT"]
        )
        return fundamental_df

    @staticmethod
    def filter_negative_per(fundamental_df):
        fundamental_df = fundamental_df[fundamental_df["PER"] > 0]
        return fundamental_df

    @staticmethod
    def append_score(fundamental_df: pd.DataFrame) -> pd.DataFrame:
        fundamental_df["PER_SCORE"] = fundamental_df["PER"].sum() / fundamental_df["PER"]
        return fundamental_df

    def __call__(self):
        fundamental_df = self.fundamental_df

        fundamental_df = self.append_per(fundamental_df)
        fundamental_df = self.filter_negative_per(fundamental_df)
        fundamental_df = self.append_score(fundamental_df)

        score_df = fundamental_df.loc[:, ["SYMBOL", "PER_SCORE"]]
        return score_df

# %%
class ROE_PROCESSOR:
    """
    ROE_PROCESSOR : ROE에 대한 정보를 SCORE로 정제하여 반환하는 클래스
    """

    def __init__(self, fundamental_df) -> None:
        self.fundamental_df = fundamental_df

    @staticmethod
    def append_roe(fundamental_df):
        fundamental_df["ROE"] = fundamental_df["NETPROFIT"] / (fundamental_df["ASSETS"])
        return fundamental_df

    @staticmethod
    def filter_negative_roe(fundamental_df):
        fundamental_df = fundamental_df[fundamental_df["ROE"] > 0]
        return fundamental_df

    @staticmethod
    def append_score(fundamental_df: pd.DataFrame) -> pd.DataFrame:
        fundamental_df["ROE_SCORE"] = fundamental_df["ROE"] / fundamental_df["ROE"].sum()
        return fundamental_df

    def __call__(self):
        fundamental_df = self.fundamental_df

        fundamental_df = self.append_roe(fundamental_df)
        fundamental_df = self.filter_negative_roe(fundamental_df)
        fundamental_df = self.append_score(fundamental_df)

        score_df = fundamental_df.loc[:, ["SYMBOL", "ROE_SCORE"]]
        return score_df

# %%
class EV_EBITDA_PROCESSOR:
    """
    EV_EBITDA_PROCESSOR : EV_EBITDA에 대한 정보를 SCORE로 정제하여 반환하는 클래스
    """

    def __init__(self, fundamental_df) -> None:
        self.fundamental_df = fundamental_df

    @staticmethod
    def append_ev_ebitda(fundamental_df):
        fundamental_df["EV_EBITDA"] = (
            fundamental_df["MARKETCAP"]
            + (fundamental_df["LIABILITIES"] - fundamental_df["CURRENT_ASSETS"])
        ) / (fundamental_df["EBITDA"])
        return fundamental_df

    @staticmethod
    def filter_negative_ev_ebitda(fundamental_df):
        fundamental_df = fundamental_df[fundamental_df["EV_EBITDA"] > 0]
        return fundamental_df

    @staticmethod
    def append_score(fundamental_df: pd.DataFrame) -> pd.DataFrame:
        fundamental_df["EV_EBITDA_SCORE"] = (
            fundamental_df["EV_EBITDA"].sum() / fundamental_df["EV_EBITDA"]
        )
        return fundamental_df

    def __call__(self):
        fundamental_df = self.fundamental_df

        fundamental_df = self.append_ev_ebitda(fundamental_df)
        fundamental_df = self.filter_negative_ev_ebitda(fundamental_df)
        fundamental_df = self.append_score(fundamental_df)

        score_df = fundamental_df.loc[:, ["SYMBOL", "EV_EBITDA_SCORE"]]
        return score_df

# %%
class BUYING_ORDER_PROCESSOR:
    """
    BUYING_ORDER_PROCESSOR : 매수주문을 생성하는 클래스
    """
    def __init__(self, score_df, invest_money, status_df, n) -> None:
        """
        BUYING_ORDER_PROCESSOR의 생성자
        
        :param pd.DataFrame score_df: symbol,score,close를 가진 데이터프레임
        :param float invest_money: 당일 활용 투자 금액
        :param pd.DataFrame status_df: 현재 position과 관련된 정보를 가진 데이터프레임
        :param int n: 당일 투자종목의 갯수
        """
        self.score_df = score_df
        self.invest_money = invest_money
        self.status_df = status_df
        self.n = n

    @staticmethod
    def filter_positioned_symbol(score_df, positioned_symbol):
        """
        이미 position이 있는 종목을 필터링 하는 메소드
        
        :param pd.DataFrame score_df: symbol,score,close를 가진 데이터프레임
        :param list positioned_symbol: 현재 이미 position이 있는 symbol의 리스트
        """
        filtered_score_df = score_df[~(score_df["SYMBOL"].isin(positioned_symbol))]
        return filtered_score_df

    @staticmethod
    def get_high_score_df(score_df, n):
        """
        score_df의 상위 n개의 row를 추출하는 메서드
        
        :param pd.DataFrame score_df: symbol,score,close를 가진 데이터프레임
        :param int n: 당일 투자종목의 갯수
        """
        high_score_df = score_df.nlargest(n, "SCORE")
        return high_score_df

    @staticmethod
    def append_price_invest(high_score_df, invest_money):
        """
        당일 활용 투자 금액을 score 기준으로 분배한 column을 생성하는 메서드
        
        :param pd.DataFrame high_score_df: score_df의 score 상위 데이터프레임
        :param float invest_money: 당일 활용 투자 금액
        """
        high_score_df["PRICE_INVEST"] = (
            high_score_df["SCORE"] / high_score_df["SCORE"].sum()
        ) * invest_money
        return high_score_df

    @staticmethod
    def append_cnt_invest(high_score_df: pd.DataFrame) -> pd.DataFrame:
        """
        당일 활용 투자 금액 최근 종가로 나누어 주문 갯수를 column으로 생성하는 메서드
        
        :param pd.DataFrame high_score_df: score_df의 score 상위 데이터프레임
        """
        high_score_df["CNT_INVEST"] = (
            high_score_df["PRICE_INVEST"] // high_score_df["CLOSE"]
        )
        return high_score_df

    @staticmethod
    def get_order_from_df(df):
        """
        데이터 프레임에서 signiture에 맞게 주문 list를 추출하는 메서드
        
        :param pd.DataFrame df: [SYMBOL,CNT_INVEST]를 가진 데이터프레임
        """
        orders = list(
            df.set_index("SYMBOL")["CNT_INVEST"].astype(int).to_dict().items()
        )
        return orders

    def __call__(self) -> list:
        """
        BUYING_ORDER_PROCESSOR의 pipeline을 진행하는 메서드
        
        """
        score_df = self.score_df
        invest_money = self.invest_money
        status_df = self.status_df
        n = self.n
        
        positioned_symbol = sorted(set(status_df["SYMBOL"]))
        filtered_positioned_df = self.filter_positioned_symbol(
            score_df, positioned_symbol
        )

        high_score_df = self.get_high_score_df(filtered_positioned_df, n)
        high_score_df = self.append_price_invest(high_score_df, invest_money)
        high_score_df = self.append_cnt_invest(high_score_df)
        buying_order = self.get_order_from_df(high_score_df)
        return buying_order

# %%
class SELLING_ORDER_PROCESSOR:
    """
    SELLING_ORDER_PROCESSOR : 매도주문을 추출하는 클래스
    """

    def __init__(self, score_df, status_df, percentage) -> None:
        """
        SELLING_ORDER_PROCESSOR의 생성자

        :param pd.DataFrame score_df: symbol,score,close를 가진 데이터프레임
        :param pd.DataFrame status_df: 현재 position과 관련된 정보를 가진 데이터프레임
        :param int percentage: low_score를 선정하기 위한 하위 (n-percent)의 기준
        """
        self.score_df = score_df
        self.status_df = status_df
        self.percentage = percentage

    @staticmethod
    def get_limit_line(score_df, percentage):
        """
        score 하위 [percentage]% 를 한계선으로 설정하고 이를 기준값을 추출

        :param pd.DataFrame score_df: symbol,score,close를 가진 데이터프레임
        :param int percentage: low_score를 선정하기 위한 하위 (n-percent)의 기준
        """
        limit_line = np.percentile(score_df["SCORE"], percentage)
        return limit_line

    @staticmethod
    def get_low_score_df(score_df: pd.DataFrame, limit_line: float) -> pd.DataFrame:
        """
        기준값을 바탕으로 low_score_df를 추출하는 메서드

        :param pd.DataFrame score_df: symbol,score,close를 가진 데이터프레임
        :param float limit_line: get_limit_line에서 추출한 하위 한계선
        """
        low_score_df = score_df[score_df["SCORE"] < limit_line]
        return low_score_df

    @staticmethod
    def get_filtered_position_symbols(
        low_score_df: pd.DataFrame, position_symbols: list
    ) -> pd.DataFrame:
        """
        low_score_df 중 position_symbol에 속하는 symbol만 추출하는 메서드

        :param pd.DataFrame low_score_df: symbol,score,close를 가진 데이터프레임
        :param list position_symbols: 현재 이미 position이 있는 symbol의 리스트
        """
        filtered_position_symbols = sorted(
            set(low_score_df["SYMBOL"]) & set(position_symbols)
        )
        return filtered_position_symbols

    @staticmethod
    def get_order_from_df(df):
        """
        데이터 프레임에서 signiture에 맞게 주문 list를 추출하는 메서드

        :param pd.DataFrame df: [SYMBOL,CURRENT_QTY]를 가진 데이터프레임
        """
        orders = list(
            df.set_index("SYMBOL")["CURRENT_QTY"]
            .apply(lambda x: x * -1)
            .astype(int)
            .to_dict()
            .items()
        )
        return orders

    def __call__(self) -> list:
        """
        SELLING_ORDER_PROCESSOR의 pipeline을 진행하는 메서드
        """
        score_df = self.score_df
        status_df = self.status_df
        percentage = self.percentage
        position_symbols = sorted(set(status_df["SYMBOL"]))

        limit_line = self.get_limit_line(score_df, percentage)
        low_score_df = self.get_low_score_df(score_df, limit_line)
        filtered_position_symbols = self.get_filtered_position_symbols(
            low_score_df, position_symbols
        )

        selling_df = status_df[status_df["SYMBOL"].isin(filtered_position_symbols)]
        selling_orders = self.get_order_from_df(selling_df)

        return selling_orders

# %%
import random
import logging
import datetime as dt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

mms = MinMaxScaler()


def trade_func(
    date: dt.date,
    dict_df_result: dict[str, pd.DataFrame],
    dict_df_position: dict[str, pd.DataFrame],
    logger: logging.Logger,
) -> list[tuple[str, int]]:
    try:
        """
        STATUS_LOADER
        """
        status_loader = STATUS_LOADER(dict_df_result, dict_df_position)

        current_cash = status_loader.get_current_cash()
        invest_money = current_cash * 0.75

        status_df = status_loader.get_status_df()
        position_symbols = sorted(set(status_df["SYMBOL"]))

        """
        SYMBOL_LOADER
        """
        symbol_loader = SYMBOL_LOADER()
        total_symbols = symbol_loader()

        sampled_symbols = random.sample(total_symbols, CFG["sampling_size"])
        using_symbols = sorted(set(sampled_symbols + position_symbols))

        """
        FUNDAMENTAL_LOADER
        """
        fundamental_data_list = list()
        for symbol in using_symbols:
            try:
                _fundamental_loader = FUNDAMENTAL_LOADER(symbol, date)
                _fundamental_data = _fundamental_loader()
                fundamental_data_list.append(_fundamental_data)
            except:
                pass
        fundamental_df = pd.DataFrame(fundamental_data_list)
        symbol_close_dict = fundamental_df.set_index("SYMBOL")["CLOSE"].to_dict()
        
        """
        PBR_PROCESSOR
        """
        pbr_processor = PBR_PROCESSOR(fundamental_df)
        pbr_score_df = pbr_processor()
        """
        PER_PROCESSOR
        """
        per_processor = PER_PROCESSOR(fundamental_df)
        per_score_df = per_processor()
        """
        ROE_PROCESSOR
        """
        roe_processor = ROE_PROCESSOR(fundamental_df)
        roe_score_df = roe_processor()
        """
        EV_EBITDA_PROCESSOR
        """
        ev_ebitda_processor = EV_EBITDA_PROCESSOR(fundamental_df)
        ev_ebitda_score_df = ev_ebitda_processor()
        score_df = (
            pbr_score_df.merge(per_score_df.loc[:, ["SYMBOL", "PER_SCORE"]], on="SYMBOL")
            .merge(roe_score_df.loc[:, ["SYMBOL", "ROE_SCORE"]], on="SYMBOL")
            .merge(ev_ebitda_score_df.loc[:, ["SYMBOL", "EV_EBITDA_SCORE"]], on="SYMBOL")
        )
        score_df.dropna(inplace=True)
        score_df.iloc[:, 1:] = mms.fit_transform(score_df.iloc[:, 1:])
        
        score_df["SCORE"] = (
            score_df["PBR_SCORE"] * 1
            + score_df["PER_SCORE"] * 1
            + score_df["ROE_SCORE"] * 1
            + score_df["EV_EBITDA_SCORE"] * 1
        )

        score_df["CLOSE"] = score_df["SYMBOL"].map(symbol_close_dict)

        """
        BUYING_ORDER_PROCESSOR
        """
        buying_order_processor = BUYING_ORDER_PROCESSOR(
            score_df, invest_money, status_df, CFG["buying_order_n"]
        )
        buying_orders = buying_order_processor()

        """
        SELLING_ORDER_PROCESSOR
        """
        selling_order_processor = SELLING_ORDER_PROCESSOR(
            score_df, status_df, CFG["selling_order_percentage"]
        )
        selling_orders = selling_order_processor()

        symbols_and_orders = buying_orders + selling_orders
        return symbols_and_orders
    except:
        return []

# %%
# loop
dict_df_result = kq.backtest_stock_port_daily(
    trade_func,
    "2023-08-01",  # 실제 심사에서는 투자기간 시작일
    "2023-08-31",  # 실제 심사에서는 투자기간 종료일
    init_cash=1_000_000_000,  # 10억원
)
# Out:
# [2023-08-01] 종목: 032190, 주문전 보유수량:      0 주문수량:  9,817, 매매수량:  9,817, 주문후 보유수량:  9,817
# [2023-08-01] 종목: 049430, 주문전 보유수량:      0 주문수량: 12,571, 매매수량: 12,571, 주문후 보유수량: 12,571
# [2023-08-01] 종목: 007860, 주문전 보유수량:      0 주문수량: 11,564, 매매수량: 11,564, 주문후 보유수량: 11,564
# [2023-08-01] 종목: 071840, 주문전 보유수량:      0 주문수량:  9,334, 매매수량:  9,334, 주문후 보유수량:  9,334
# [2023-08-01] 종목: 126720, 주문전 보유수량:      0 주문수량:  4,223, 매매수량:  4,223, 주문후 보유수량:  4,223
# [2023-08-01] 종목: 123040, 주문전 보유수량:      0 주문수량: 15,280, 매매수량: 15,280, 주문후 보유수량: 15,280
# [2023-08-01] 종목: 122310, 주문전 보유수량:      0 주문수량: 10,638, 매매수량: 10,638, 주문후 보유수량: 10,638
# [2023-08-01] 종목: 353200, 주문전 보유수량:      0 주문수량:  1,993, 매매수량:  1,993, 주문후 보유수량:  1,993
# [2023-08-02] 종목: 094840, 주문전 보유수량:      0 주문수량:  4,935, 매매수량:  4,935, 주문후 보유수량:  4,935
# [2023-08-02] 종목: 040610, 주문전 보유수량:      0 주문수량: 18,171, 매매수량: 18,171, 주문후 보유수량: 18,171
# [2023-08-02] 종목: 332370, 주문전 보유수량:      0 주문수량:  6,501, 매매수량:  6,501, 주문후 보유수량:  6,501
# [2023-08-02] 종목: 054040, 주문전 보유수량:      0 주문수량:  5,221, 매매수량:  5,221, 주문후 보유수량:  5,221
# [2023-08-02] 종목: 340570, 주문전 보유수량:      0 주문수량:    420, 매매수량:    420, 주문후 보유수량:    420
# [2023-08-02] 종목: 034810, 주문전 보유수량:      0 주문수량:  2,248, 매매수량:  2,248, 주문후 보유수량:  2,248
# [2023-08-02] 종목: 009200, 주문전 보유수량:      0 주문수량:  7,733, 매매수량:  7,733, 주문후 보유수량:  7,733
# [2023-08-02] 종목: 079940, 주문전 보유수량:      0 주문수량:  1,531, 매매수량:  1,531, 주문후 보유수량:  1,531
# [2023-08-03] 종목: 297890, 주문전 보유수량:      0 주문수량:  1,787, 매매수량:  1,787, 주문후 보유수량:  1,787
# [2023-08-03] 종목: 003380, 주문전 보유수량:      0 주문수량:  1,028, 매매수량:  1,028, 주문후 보유수량:  1,028
# [2023-08-03] 종목: 058650, 주문전 보유수량:      0 주문수량:     58, 매매수량:     58, 주문후 보유수량:     58
# [2023-08-03] 종목: 348210, 주문전 보유수량:      0 주문수량:     75, 매매수량:     75, 주문후 보유수량:     75
# [2023-08-03] 종목: 006360, 주문전 보유수량:      0 주문수량:    335, 매매수량:    335, 주문후 보유수량:    335
# [2023-08-03] 종목: 215000, 주문전 보유수량:      0 주문수량:     48, 매매수량:     48, 주문후 보유수량:     48
# [2023-08-03] 종목: 180640, 주문전 보유수량:      0 주문수량:    106, 매매수량:    106, 주문후 보유수량:    106
# [2023-08-03] 종목: 046390, 주문전 보유수량:      0 주문수량:  1,912, 매매수량:  1,912, 주문후 보유수량:  1,912
# [2023-08-07] 종목: 151860, 주문전 보유수량:      0 주문수량:    270, 매매수량:    270, 주문후 보유수량:    270
# [2023-08-07] 종목: 000880, 주문전 보유수량:      0 주문수량:     71, 매매수량:     71, 주문후 보유수량:     71
# [2023-08-07] 종목: 005440, 주문전 보유수량:      0 주문수량:    478, 매매수량:    478, 주문후 보유수량:    478
# [2023-08-07] 종목: 383220, 주문전 보유수량:      0 주문수량:     11, 매매수량:     11, 주문후 보유수량:     11
# [2023-08-07] 종목: 121440, 주문전 보유수량:      0 주문수량:    272, 매매수량:    272, 주문후 보유수량:    272
# [2023-08-07] 종목: 138930, 주문전 보유수량:      0 주문수량:    146, 매매수량:    146, 주문후 보유수량:    146
# [2023-08-07] 종목: 042700, 주문전 보유수량:      0 주문수량:     17, 매매수량:     17, 주문후 보유수량:     17
# [2023-08-07] 종목: 230360, 주문전 보유수량:      0 주문수량:     74, 매매수량:     74, 주문후 보유수량:     74
# [2023-08-08] 종목: 042700, 주문전 보유수량:     17 주문수량:    -17, 매매수량:    -17, 주문후 보유수량:      0
# [2023-08-08] 종목: 340570, 주문전 보유수량:    420 주문수량:   -420, 매매수량:   -420, 주문후 보유수량:      0
# [2023-08-08] 종목: 106240, 주문전 보유수량:      0 주문수량:    430, 매매수량:    430, 주문후 보유수량:    430
# [2023-08-08] 종목: 375500, 주문전 보유수량:      0 주문수량:     15, 매매수량:     15, 주문후 보유수량:     15
# [2023-08-08] 종목: 006120, 주문전 보유수량:      0 주문수량:     10, 매매수량:     10, 주문후 보유수량:     10
# [2023-08-08] 종목: 001040, 주문전 보유수량:      0 주문수량:      5, 매매수량:      5, 주문후 보유수량:      5
# [2023-08-08] 종목: 013580, 주문전 보유수량:      0 주문수량:     17, 매매수량:     17, 주문후 보유수량:     17
# [2023-08-08] 종목: 082850, 주문전 보유수량:      0 주문수량:    121, 매매수량:    121, 주문후 보유수량:    121
# [2023-08-08] 종목: 057050, 주문전 보유수량:      0 주문수량:      5, 매매수량:      5, 주문후 보유수량:      5
# [2023-08-08] 종목: 023600, 주문전 보유수량:      0 주문수량:     22, 매매수량:     22, 주문후 보유수량:     22
# [2023-08-09] 종목: 000850, 주문전 보유수량:      0 주문수량:    130, 매매수량:    130, 주문후 보유수량:    130
# [2023-08-09] 종목: 012630, 주문전 보유수량:      0 주문수량:    612, 매매수량:    612, 주문후 보유수량:    612
# [2023-08-09] 종목: 002030, 주문전 보유수량:      0 주문수량:      9, 매매수량:      9, 주문후 보유수량:      9
# [2023-08-09] 종목: 225590, 주문전 보유수량:      0 주문수량:  1,164, 매매수량:  1,164, 주문후 보유수량:  1,164
# [2023-08-09] 종목: 035810, 주문전 보유수량:      0 주문수량:    540, 매매수량:    540, 주문후 보유수량:    540
# [2023-08-09] 종목: 004720, 주문전 보유수량:      0 주문수량:    245, 매매수량:    245, 주문후 보유수량:    245
# [2023-08-09] 종목: 129260, 주문전 보유수량:      0 주문수량:    619, 매매수량:    619, 주문후 보유수량:    619
# [2023-08-09] 종목: 067830, 주문전 보유수량:      0 주문수량:    482, 매매수량:    482, 주문후 보유수량:    482
# [2023-08-10] 종목: 036710, 주문전 보유수량:      0 주문수량:    309, 매매수량:    309, 주문후 보유수량:    309
# [2023-08-10] 종목: 005740, 주문전 보유수량:      0 주문수량:    120, 매매수량:    120, 주문후 보유수량:    120
# [2023-08-10] 종목: 000210, 주문전 보유수량:      0 주문수량:     14, 매매수량:     14, 주문후 보유수량:     14
# [2023-08-10] 종목: 009410, 주문전 보유수량:      0 주문수량:    141, 매매수량:    141, 주문후 보유수량:    141
# [2023-08-10] 종목: 017650, 주문전 보유수량:      0 주문수량:     57, 매매수량:     57, 주문후 보유수량:     57
# [2023-08-10] 종목: 002310, 주문전 보유수량:      0 주문수량:     12, 매매수량:     12, 주문후 보유수량:     12
# [2023-08-10] 종목: 049070, 주문전 보유수량:      0 주문수량:     13, 매매수량:     13, 주문후 보유수량:     13
# [2023-08-10] 종목: 213500, 주문전 보유수량:      0 주문수량:     37, 매매수량:     37, 주문후 보유수량:     37
# [2023-08-11] 종목: 001390, 주문전 보유수량:      0 주문수량:     32, 매매수량:     32, 주문후 보유수량:     32
# [2023-08-11] 종목: 007700, 주문전 보유수량:      0 주문수량:     10, 매매수량:     10, 주문후 보유수량:     10
# [2023-08-11] 종목: 004840, 주문전 보유수량:      0 주문수량:     28, 매매수량:     28, 주문후 보유수량:     28
# [2023-08-11] 종목: 017940, 주문전 보유수량:      0 주문수량:      2, 매매수량:      2, 주문후 보유수량:      2
# [2023-08-11] 종목: 115570, 주문전 보유수량:      0 주문수량:     29, 매매수량:     29, 주문후 보유수량:     29
# [2023-08-11] 종목: 054940, 주문전 보유수량:      0 주문수량:     92, 매매수량:     92, 주문후 보유수량:     92
# [2023-08-11] 종목: 122690, 주문전 보유수량:      0 주문수량:     25, 매매수량:     25, 주문후 보유수량:     25
# [2023-08-11] 종목: 265520, 주문전 보유수량:      0 주문수량:      4, 매매수량:      4, 주문후 보유수량:      4
# [2023-08-14] 종목: 230360, 주문전 보유수량:     74 주문수량:    -74, 매매수량:    -74, 주문후 보유수량:      0
# [2023-08-14] 종목: 031330, 주문전 보유수량:      0 주문수량:     19, 매매수량:     19, 주문후 보유수량:     19
# [2023-08-14] 종목: 021320, 주문전 보유수량:      0 주문수량:      9, 매매수량:      9, 주문후 보유수량:      9
# [2023-08-14] 종목: 050120, 주문전 보유수량:      0 주문수량:     10, 매매수량:     10, 주문후 보유수량:     10
# [2023-08-14] 종목: 013870, 주문전 보유수량:      0 주문수량:      5, 매매수량:      5, 주문후 보유수량:      5
# [2023-08-14] 종목: 072950, 주문전 보유수량:      0 주문수량:      5, 매매수량:      5, 주문후 보유수량:      5
# [2023-08-16] 종목: 072950, 주문전 보유수량:      5 주문수량:     -5, 매매수량:     -5, 주문후 보유수량:      0
# [2023-08-16] 종목: 001230, 주문전 보유수량:      0 주문수량:     28, 매매수량:     28, 주문후 보유수량:     28
# [2023-08-16] 종목: 363280, 주문전 보유수량:      0 주문수량:     11, 매매수량:     11, 주문후 보유수량:     11
# [2023-08-16] 종목: 002320, 주문전 보유수량:      0 주문수량:      3, 매매수량:      3, 주문후 보유수량:      3
# [2023-08-16] 종목: 377460, 주문전 보유수량:      0 주문수량:     15, 매매수량:     15, 주문후 보유수량:     15
# [2023-08-16] 종목: 001120, 주문전 보유수량:      0 주문수량:      1, 매매수량:      1, 주문후 보유수량:      1
# [2023-08-16] 종목: 004590, 주문전 보유수량:      0 주문수량:     11, 매매수량:     11, 주문후 보유수량:     11
# [2023-08-16] 종목: 004430, 주문전 보유수량:      0 주문수량:      2, 매매수량:      2, 주문후 보유수량:      2
# [2023-08-17] 종목: 036460, 주문전 보유수량:      0 주문수량:      1, 매매수량:      1, 주문후 보유수량:      1
# [2023-08-17] 종목: 101330, 주문전 보유수량:      0 주문수량:     14, 매매수량:     14, 주문후 보유수량:     14
# [2023-08-17] 종목: 005960, 주문전 보유수량:      0 주문수량:      7, 매매수량:      7, 주문후 보유수량:      7
# [2023-08-17] 종목: 027410, 주문전 보유수량:      0 주문수량:     10, 매매수량:     10, 주문후 보유수량:     10
# [2023-08-17] 종목: 127710, 주문전 보유수량:      0 주문수량:     27, 매매수량:     27, 주문후 보유수량:     27
# [2023-08-17] 종목: 267290, 주문전 보유수량:      0 주문수량:      1, 매매수량:      1, 주문후 보유수량:      1
# [2023-08-18] 종목: 122310, 주문전 보유수량: 10,638 주문수량: -10,638, 매매수량: -10,638, 주문후 보유수량:      0
# [2023-08-18] 종목: 353200, 주문전 보유수량:  1,993 주문수량: -1,993, 매매수량: -1,993, 주문후 보유수량:      0
# [2023-08-18] 종목: 016250, 주문전 보유수량:      0 주문수량:      1, 매매수량:      1, 주문후 보유수량:      1
# [2023-08-18] 종목: 008370, 주문전 보유수량:      0 주문수량:      4, 매매수량:      4, 주문후 보유수량:      4
# [2023-08-18] 종목: 031820, 주문전 보유수량:      0 주문수량:     23, 매매수량:     23, 주문후 보유수량:     23
# [2023-08-18] 종목: 123890, 주문전 보유수량:      0 주문수량:      5, 매매수량:      5, 주문후 보유수량:      5
# [2023-08-18] 종목: 253840, 주문전 보유수량:      0 주문수량:      2, 매매수량:      2, 주문후 보유수량:      2
# [2023-08-18] 종목: 038540, 주문전 보유수량:      0 주문수량:      3, 매매수량:      3, 주문후 보유수량:      3
# [2023-08-21] 종목: 084690, 주문전 보유수량:      0 주문수량:  2,678, 매매수량:  2,678, 주문후 보유수량:  2,678
# [2023-08-21] 종목: 000670, 주문전 보유수량:      0 주문수량:     32, 매매수량:     32, 주문후 보유수량:     32
# [2023-08-21] 종목: 039020, 주문전 보유수량:      0 주문수량:  4,552, 매매수량:  4,552, 주문후 보유수량:  4,552
# [2023-08-21] 종목: 086790, 주문전 보유수량:      0 주문수량:    272, 매매수량:    272, 주문후 보유수량:    272
# [2023-08-21] 종목: 005090, 주문전 보유수량:      0 주문수량:    383, 매매수량:    383, 주문후 보유수량:    383
# [2023-08-21] 종목: 034830, 주문전 보유수량:      0 주문수량:  7,386, 매매수량:  7,386, 주문후 보유수량:  7,386
# [2023-08-21] 종목: 058630, 주문전 보유수량:      0 주문수량:  1,290, 매매수량:  1,290, 주문후 보유수량:  1,290
# [2023-08-21] 종목: 065680, 주문전 보유수량:      0 주문수량:    606, 매매수량:    606, 주문후 보유수량:    606
# [2023-08-22] 종목: 192440, 주문전 보유수량:      0 주문수량:    109, 매매수량:    109, 주문후 보유수량:    109
# [2023-08-22] 종목: 005990, 주문전 보유수량:      0 주문수량:    398, 매매수량:    398, 주문후 보유수량:    398
# [2023-08-22] 종목: 003300, 주문전 보유수량:      0 주문수량:    302, 매매수량:    302, 주문후 보유수량:    302
# [2023-08-22] 종목: 093050, 주문전 보유수량:      0 주문수량:    233, 매매수량:    233, 주문후 보유수량:    233
# [2023-08-22] 종목: 002020, 주문전 보유수량:      0 주문수량:    182, 매매수량:    182, 주문후 보유수량:    182
# [2023-08-22] 종목: 001800, 주문전 보유수량:      0 주문수량:    215, 매매수량:    215, 주문후 보유수량:    215
# [2023-08-22] 종목: 111770, 주문전 보유수량:      0 주문수량:     36, 매매수량:     36, 주문후 보유수량:     36
# [2023-08-22] 종목: 201490, 주문전 보유수량:      0 주문수량:    643, 매매수량:    643, 주문후 보유수량:    643
# [2023-08-25] 종목: 039560, 주문전 보유수량:      0 주문수량:    256, 매매수량:    256, 주문후 보유수량:    256
# [2023-08-25] 종목: 007160, 주문전 보유수량:      0 주문수량:     20, 매매수량:     20, 주문후 보유수량:     20
# [2023-08-25] 종목: 204610, 주문전 보유수량:      0 주문수량:    588, 매매수량:    588, 주문후 보유수량:    588
# [2023-08-25] 종목: 005810, 주문전 보유수량:      0 주문수량:     20, 매매수량:     20, 주문후 보유수량:     20
# [2023-08-25] 종목: 015230, 주문전 보유수량:      0 주문수량:     99, 매매수량:     99, 주문후 보유수량:     99
# [2023-08-25] 종목: 003960, 주문전 보유수량:      0 주문수량:     22, 매매수량:     22, 주문후 보유수량:     22
# [2023-08-25] 종목: 005320, 주문전 보유수량:      0 주문수량:    704, 매매수량:    704, 주문후 보유수량:    704
# [2023-08-25] 종목: 036090, 주문전 보유수량:      0 주문수량:    822, 매매수량:    822, 주문후 보유수량:    822
# [2023-08-28] 종목: 005320, 주문전 보유수량:    704 주문수량:   -704, 매매수량:   -704, 주문후 보유수량:      0
# [2023-08-28] 종목: 015230, 주문전 보유수량:     99 주문수량:    -99, 매매수량:    -99, 주문후 보유수량:      0
# [2023-08-28] 종목: 046390, 주문전 보유수량:  1,912 주문수량: -1,912, 매매수량: -1,912, 주문후 보유수량:      0
# [2023-08-28] 종목: 054940, 주문전 보유수량:     92 주문수량:    -92, 매매수량:    -92, 주문후 보유수량:      0
# [2023-08-28] 종목: 065680, 주문전 보유수량:    606 주문수량:   -606, 매매수량:   -606, 주문후 보유수량:      0
# [2023-08-28] 종목: 079940, 주문전 보유수량:  1,531 주문수량: -1,531, 매매수량: -1,531, 주문후 보유수량:      0
# [2023-08-28] 종목: 082850, 주문전 보유수량:    121 주문수량:   -121, 매매수량:   -121, 주문후 보유수량:      0
# [2023-08-28] 종목: 126720, 주문전 보유수량:  4,223 주문수량: -4,223, 매매수량: -4,223, 주문후 보유수량:      0
# [2023-08-28] 종목: 204610, 주문전 보유수량:    588 주문수량:   -588, 매매수량:   -588, 주문후 보유수량:      0
# [2023-08-28] 종목: 297890, 주문전 보유수량:  1,787 주문수량: -1,787, 매매수량: -1,787, 주문후 보유수량:      0
# [2023-08-28] 종목: 104480, 주문전 보유수량:      0 주문수량:    161, 매매수량:    161, 주문후 보유수량:    161
# [2023-08-28] 종목: 005720, 주문전 보유수량:      0 주문수량:     70, 매매수량:     70, 주문후 보유수량:     70
# [2023-08-28] 종목: 023590, 주문전 보유수량:      0 주문수량:     14, 매매수량:     14, 주문후 보유수량:     14
# [2023-08-28] 종목: 004150, 주문전 보유수량:      0 주문수량:     73, 매매수량:     73, 주문후 보유수량:     73
# [2023-08-28] 종목: 383800, 주문전 보유수량:      0 주문수량:     17, 매매수량:     17, 주문후 보유수량:     17
# [2023-08-28] 종목: 072710, 주문전 보유수량:      0 주문수량:      1, 매매수량:      1, 주문후 보유수량:      1
# [2023-08-28] 종목: 290120, 주문전 보유수량:      0 주문수량:     26, 매매수량:     26, 주문후 보유수량:     26
# [2023-08-28] 종목: 013520, 주문전 보유수량:      0 주문수량:     63, 매매수량:     63, 주문후 보유수량:     63
# [2023-08-29] 종목: 036090, 주문전 보유수량:    822 주문수량:   -822, 매매수량:   -822, 주문후 보유수량:      0
# [2023-08-29] 종목: 058630, 주문전 보유수량:  1,290 주문수량: -1,290, 매매수량: -1,290, 주문후 보유수량:      0
# [2023-08-29] 종목: 180640, 주문전 보유수량:    106 주문수량:   -106, 매매수량:   -106, 주문후 보유수량:      0
# [2023-08-29] 종목: 215000, 주문전 보유수량:     48 주문수량:    -48, 매매수량:    -48, 주문후 보유수량:      0
# [2023-08-29] 종목: 383220, 주문전 보유수량:     11 주문수량:    -11, 매매수량:    -11, 주문후 보유수량:      0
# [2023-08-29] 종목: 139480, 주문전 보유수량:      0 주문수량:    264, 매매수량:    264, 주문후 보유수량:    264
# [2023-08-29] 종목: 034730, 주문전 보유수량:      0 주문수량:    135, 매매수량:    135, 주문후 보유수량:    135
# [2023-08-29] 종목: 014790, 주문전 보유수량:      0 주문수량:  5,777, 매매수량:  5,777, 주문후 보유수량:  5,777
# [2023-08-29] 종목: 065680, 주문전 보유수량:      0 주문수량:    897, 매매수량:    897, 주문후 보유수량:    897
# [2023-08-29] 종목: 054050, 주문전 보유수량:      0 주문수량:  1,150, 매매수량:  1,150, 주문후 보유수량:  1,150
# [2023-08-29] 종목: 306040, 주문전 보유수량:      0 주문수량:    899, 매매수량:    899, 주문후 보유수량:    899
# [2023-08-29] 종목: 045100, 주문전 보유수량:      0 주문수량:    531, 매매수량:    531, 주문후 보유수량:    531
# [2023-08-29] 종목: 001250, 주문전 보유수량:      0 주문수량:  3,240, 매매수량:  3,240, 주문후 보유수량:  3,240
# [2023-08-30] 종목: 001250, 주문전 보유수량:  3,240 주문수량: -3,240, 매매수량: -3,240, 주문후 보유수량:      0
# [2023-08-30] 종목: 004590, 주문전 보유수량:     11 주문수량:    -11, 매매수량:    -11, 주문후 보유수량:      0
# [2023-08-30] 종목: 005090, 주문전 보유수량:    383 주문수량:   -383, 매매수량:   -383, 주문후 보유수량:      0
# [2023-08-30] 종목: 013520, 주문전 보유수량:     63 주문수량:    -63, 매매수량:    -63, 주문후 보유수량:      0
# [2023-08-30] 종목: 034830, 주문전 보유수량:  7,386 주문수량: -7,386, 매매수량: -7,386, 주문후 보유수량:      0
# [2023-08-30] 종목: 038540, 주문전 보유수량:      3 주문수량:     -3, 매매수량:     -3, 주문후 보유수량:      0
# [2023-08-30] 종목: 086790, 주문전 보유수량:    272 주문수량:   -272, 매매수량:   -272, 주문후 보유수량:      0
# [2023-08-30] 종목: 122690, 주문전 보유수량:     25 주문수량:    -25, 매매수량:    -25, 주문후 보유수량:      0
# [2023-08-30] 종목: 123040, 주문전 보유수량: 15,280 주문수량: -15,280, 매매수량: -15,280, 주문후 보유수량:      0
# [2023-08-30] 종목: 265520, 주문전 보유수량:      4 주문수량:     -4, 매매수량:     -4, 주문후 보유수량:      0
# [2023-08-30] 종목: 003030, 주문전 보유수량:      0 주문수량:     44, 매매수량:     44, 주문후 보유수량:     44
# [2023-08-30] 종목: 039010, 주문전 보유수량:      0 주문수량:  1,019, 매매수량:  1,019, 주문후 보유수량:  1,019
# [2023-08-30] 종목: 000860, 주문전 보유수량:      0 주문수량:    237, 매매수량:    237, 주문후 보유수량:    237
# [2023-08-30] 종목: 088350, 주문전 보유수량:      0 주문수량:  2,024, 매매수량:  2,024, 주문후 보유수량:  2,024
# [2023-08-30] 종목: 194370, 주문전 보유수량:      0 주문수량:    343, 매매수량:    343, 주문후 보유수량:    343
# [2023-08-30] 종목: 058630, 주문전 보유수량:      0 주문수량:    542, 매매수량:    542, 주문후 보유수량:    542
# [2023-08-30] 종목: 180640, 주문전 보유수량:      0 주문수량:     79, 매매수량:     79, 주문후 보유수량:     79
# [2023-08-30] 종목: 322000, 주문전 보유수량:      0 주문수량:    106, 매매수량:    106, 주문후 보유수량:    106
# [2023-08-31] 종목: 058630, 주문전 보유수량:    542 주문수량:   -542, 매매수량:   -542, 주문후 보유수량:      0
# [2023-08-31] 종목: 180640, 주문전 보유수량:     79 주문수량:    -79, 매매수량:    -79, 주문후 보유수량:      0
# [2023-08-31] 종목: 322000, 주문전 보유수량:    106 주문수량:   -106, 매매수량:   -106, 주문후 보유수량:      0
# [2023-08-31] 종목: 006390, 주문전 보유수량:      0 주문수량:  1,351, 매매수량:  1,351, 주문후 보유수량:  1,351
# [2023-08-31] 종목: 024800, 주문전 보유수량:      0 주문수량:  9,125, 매매수량:  9,125, 주문후 보유수량:  9,125
# [2023-08-31] 종목: 002240, 주문전 보유수량:      0 주문수량:    536, 매매수량:    536, 주문후 보유수량:    536
# [2023-08-31] 종목: 016590, 주문전 보유수량:      0 주문수량:  2,060, 매매수량:  2,060, 주문후 보유수량:  2,060
# [2023-08-31] 종목: 004690, 주문전 보유수량:      0 주문수량:     89, 매매수량:     89, 주문후 보유수량:     89
# [2023-08-31] 종목: 091590, 주문전 보유수량:      0 주문수량:  1,185, 매매수량:  1,185, 주문후 보유수량:  1,185
# [2023-08-31] 종목: 014280, 주문전 보유수량:      0 주문수량:  1,504, 매매수량:  1,504, 주문후 보유수량:  1,504
# [2023-08-31] 종목: 014440, 주문전 보유수량:      0 주문수량:  2,637, 매매수량:  2,637, 주문후 보유수량:  2,637

# %%
print("HEllo")
# Out:
# HEllo

# %%
dict_df_result['TOTAL']['TOTAL_VALUE'].tail(1)
# Out:
# 18    1,001,182,565
# Name: TOTAL_VALUE, dtype: int64
